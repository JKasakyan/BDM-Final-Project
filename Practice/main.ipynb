# %%
from Scripts.police_reports import get_rdd as get_accident_rdd
from Scripts.three_one_one import get_rdd as get_three_one_one_rdd
from Scripts.vehicle_volume_count import get_rdd as get_vehicle_rdd

accident_rdd      = get_accident_rdd(sc, "../Datasets/NYPD_Motor_Vehicle_Collisions.csv", download=False, output_path="FinalProjectOutputs")
three_one_one_rdd = get_three_one_one_rdd(sc, "../Datasets/311_Service_Requests_from_2010_to_Present.csv", download=False, output_path="FinalProjectOutputs")
count_rdd = get_vehicle_rdd(sc, "../Datasets/zip_veh_count.csv", download=False, output_path="FinalProjectOutputs")

joined_rdd        = count_rdd.join(accident_rdd.join(three_one_one_rdd))

# %%
accident_rdd      = get_accident_rdd(sc, "../Datasets/NYPD_Motor_Vehicle_Collisions.csv", download=False, output_path="FinalProjectOutputs")
count_rdd = get_vehicle_rdd(sc, "../Datasets/zip_veh_count.csv", download=False, output_path="FinalProjectOutputs")
joined_rdd = count_rdd.join(accident_rdd.join(three_one_one_rdd))
joined_rdd.cache()
joined_rdd.collect()
# Out:
# [(u'10314',
#   (20626627,
#    ((2297,
#      4582,
#      551,
#      4,
#      '78: 14.0%',
#      '2: 50.0%',
#      '3: 1.0%',
#      '0: 0.0%',
#      '470: 85.0%',
#      '2: 50.0%',
#      'Driver Inattention/Distraction: 281: 6.13%',
#      'Fatigued/Drowsy: 154: 3.36%',
#      'Failure to Yield Right-of-Way: 92: 2.01%',
#      'Pavement Slippery: 70: 1.53%',
#      'Other Vehicular: 52: 1.13%',
#      'PASSENGER VEHICLE: 3124: 68.18%',
#      'SPORT UTILITY / STATION WAGON: 950: 20.73%',
#      'OTHER: 75: 1.64%',
#      'PICK-UP TRUCK: 56: 1.22%',
#      'VAN: 53: 1.16%'),
#     (1,
#      'STREET LIGHT CONDITION: 1: 100.0%',
#      '',
#      '',
#      'Street Light Out: 1: 100.0%',
#      '',
#      '',
#      '',
#      '',
#      'STATEN ISLAND')))),
#  (u'11232',
#   (6344349,
#    ((1351,
#      2684,
#      309,
#      0,
#      '77: 25.0%',
#      '0: 0.0%',
#      '48: 16.0%',
#      '0: 0.0%',
#      '184: 60.0%',
#      '0: 0.0%',
#      'Driver Inattention/Distraction: 195: 7.27%',
#      'Failure to Yield Right-of-Way: 82: 3.06%',
#      'Backing Unsafely: 80: 2.98%',
#      'Fatigued/Drowsy: 62: 2.31%',
#      'Driver Inexperience: 50: 1.86%',
#      'PASSENGER VEHICLE: 1652: 61.55%',
#      'SPORT UTILITY / STATION WAGON: 309: 11.51%',
#      'SMALL COM VEH(4 TIRES): 115: 4.28%',
#      'VAN: 109: 4.06%',
#      'LARGE COM VEH(6 OR MORE TIRES): 107: 3.99%'),
#     (1,
#      'STREET LIGHT CONDITION: 1: 100.0%',
#      '',
#      '',
#      'Street Light Dayburning: 1: 100.0%',
#      '',
#      '',
#      '',
#      '',
#      'BROOKLYN')))),
#  (u'11233',
#   (8261762,
#    ((2081,
#      4116,
#      877,
#      2,
#      '192: 22.0%',
#      '0: 0.0%',
#      '58: 7.0%',
#      '0: 0.0%',
#      '627: 71.0%',
#      '2: 100.0%',
#      'Driver Inattention/Distraction: 182: 4.42%',
#      'Fatigued/Drowsy: 64: 1.55%',
#      'Failure to Yield Right-of-Way: 59: 1.43%',
#      'Turning Improperly: 31: 0.75%',
#      'Prescription Medication: 30: 0.73%',
#      'PASSENGER VEHICLE: 2470: 60.01%',
#      'SPORT UTILITY / STATION WAGON: 823: 20.0%',
#      'VAN: 88: 2.14%',
#      'OTHER: 78: 1.9%',
#      'BICYCLE: 73: 1.77%'),
#     (1,
#      'STREET LIGHT CONDITION: 1: 100.0%',
#      '',
#      '',
#      'Street Light Out: 1: 100.0%',
#      '',
#      '',
#      '',
#      '',
#      'BROOKLYN')))),
#  (u'10003',
#   (11829042,
#    ((2164,
#      4155,
#      456,
#      2,
#      '193: 42.0%',
#      '2: 100.0%',
#      '109: 24.0%',
#      '0: 0.0%',
#      '154: 34.0%',
#      '0: 0.0%',
#      'Driver Inattention/Distraction: 225: 5.42%',
#      'Fatigued/Drowsy: 79: 1.9%',
#      'Lost Consciousness: 67: 1.61%',
#      'Backing Unsafely: 61: 1.47%',
#      'Failure to Yield Right-of-Way: 58: 1.4%',
#      'PASSENGER VEHICLE: 1621: 39.01%',
#      'TAXI: 855: 20.58%',
#      'SPORT UTILITY / STATION WAGON: 475: 11.43%',
#      'VAN: 200: 4.81%',
#      'BICYCLE: 154: 3.71%'),
#     (1,
#      'STREET CONDITION: 1: 100.0%',
#      '',
#      '',
#      'Pothole: 1: 100.0%',
#      '',
#      '',
#      '',
#      '',
#      'NEW YORK')))),
#  (u'11364',
#   (10214994,
#    ((646,
#      1283,
#      153,
#      4,
#      '26: 17.0%',
#      '2: 50.0%',
#      '7: 5.0%',
#      '0: 0.0%',
#      '120: 78.0%',
#      '2: 50.0%',
#      'Driver Inattention/Distraction: 122: 9.51%',
#      'Failure to Yield Right-of-Way: 111: 8.65%',
#      'Fatigued/Drowsy: 65: 5.07%',
#      'Backing Unsafely: 54: 4.21%',
#      'Prescription Medication: 30: 2.34%',
#      'PASSENGER VEHICLE: 744: 57.99%',
#      'SPORT UTILITY / STATION WAGON: 369: 28.76%',
#      'VAN: 31: 2.42%',
#      'BUS: 16: 1.25%',
#      'OTHER: 15: 1.17%'),
#     (1,
#      'STREET LIGHT CONDITION: 1: 100.0%',
#      '',
#      '',
#      'Street Light Out: 1: 100.0%',
#      '',
#      '',
#      '',
#      '',
#      'Oakland Gardens')))),
#  (u'11207',
#   (15605388,
#    ((4050,
#      8088,
#      1730,
#      4,
#      '279: 16.0%',
#      '3: 75.0%',
#      '110: 6.0%',
#      '0: 0.0%',
#      '1341: 78.0%',
#      '1: 25.0%',
#      'Driver Inattention/Distraction: 127: 1.57%',
#      'Failure to Yield Right-of-Way: 59: 0.73%',
#      'Other Vehicular: 50: 0.62%',
#      'Fatigued/Drowsy: 42: 0.52%',
#      'Backing Unsafely: 26: 0.32%',
#      'PASSENGER VEHICLE: 5041: 62.33%',
#      'SPORT UTILITY / STATION WAGON: 1297: 16.04%',
#      'OTHER: 374: 4.62%',
#      'VAN: 192: 2.37%',
#      'BICYCLE: 119: 1.47%'),
#     (1,
#      'STREET LIGHT CONDITION: 1: 100.0%',
#      '',
#      '',
#      'Street Light Dayburning: 1: 100.0%',
#      '',
#      '',
#      '',
#      '',
#      'BROOKLYN')))),
#  (u'11208',
#   (47601258,
#    ((2232,
#      4438,
#      890,
#      5,
#      '167: 19.0%',
#      '1: 20.0%',
#      '50: 6.0%',
#      '0: 0.0%',
#      '673: 76.0%',
#      '4: 80.0%',
#      'Driver Inattention/Distraction: 88: 1.98%',
#      'Failure to Yield Right-of-Way: 39: 0.88%',
#      'Other Vehicular: 34: 0.77%',
#      'Physical Disability: 18: 0.41%',
#      'Traffic Control Disregarded: 17: 0.38%',
#      'PASSENGER VEHICLE: 2781: 62.66%',
#      'SPORT UTILITY / STATION WAGON: 698: 15.73%',
#      'VAN: 91: 2.05%',
#      'OTHER: 82: 1.85%',
#      'PICK-UP TRUCK: 64: 1.44%'),
#     (1,
#      'STREET CONDITION: 1: 100.0%',
#      '',
#      '',
#      'Pothole: 1: 100.0%',
#      '',
#      '',
#      '',
#      '',
#      'BROOKLYN')))),
#  (u'11226',
#   (12648493,
#    ((2464,
#      4874,
#      1009,
#      2,
#      '291: 29.0%',
#      '2: 100.0%',
#      '91: 9.0%',
#      '0: 0.0%',
#      '627: 62.0%',
#      '0: 0.0%',
#      'Driver Inattention/Distraction: 154: 3.16%',
#      'Fatigued/Drowsy: 69: 1.42%',
#      'Failure to Yield Right-of-Way: 61: 1.25%',
#      'Other Vehicular: 51: 1.05%',
#      'Backing Unsafely: 40: 0.82%',
#      'PASSENGER VEHICLE: 2543: 52.17%',
#      'SPORT UTILITY / STATION WAGON: 1229: 25.22%',
#      'VAN: 200: 4.1%',
#      'BICYCLE: 113: 2.32%',
#      'BUS: 94: 1.93%'),
#     (1,
#      'STREET SIGN - DAMAGED: 1: 100.0%',
#      '',
#      '',
#      'Street Cleaning - ASP: 1: 100.0%',
#      '',
#      '',
#      '',
#      '',
#      'BROOKLYN')))),
#  (u'10032',
#   (8956943,
#    ((1134,
#      2193,
#      343,
#      1,
#      '112: 33.0%',
#      '1: 100.0%',
#      '19: 6.0%',
#      '0: 0.0%',
#      '212: 62.0%',
#      '0: 0.0%',
#      'Driver Inattention/Distraction: 67: 3.06%',
#      'Other Vehicular: 41: 1.87%',
#      'Failure to Yield Right-of-Way: 32: 1.46%',
#      'Fatigued/Drowsy: 23: 1.05%',
#      'Backing Unsafely: 22: 1.0%',
#      'PASSENGER VEHICLE: 1051: 47.93%',
#      'SPORT UTILITY / STATION WAGON: 439: 20.02%',
#      'OTHER: 140: 6.38%',
#      'VAN: 101: 4.61%',
#      'TAXI: 87: 3.97%'),
#     (1,
#      'STREET CONDITION: 1: 100.0%',
#      '',
#      '',
#      'Pothole: 1: 100.0%',
#      '',
#      '',
#      '',
#      '',
#      'NEW YORK')))),
#  (u'10019',
#   (19802790,
#    ((3307,
#      6415,
#      474,
#      3,
#      '190: 40.0%',
#      '2: 67.0%',
#      '74: 16.0%',
#      '0: 0.0%',
#      '210: 44.0%',
#      '1: 33.0%',
#      'Driver Inattention/Distraction: 1051: 16.38%',
#      'Fatigued/Drowsy: 427: 6.66%',
#      'Turning Improperly: 369: 5.75%',
#      'Lost Consciousness: 314: 4.89%',
#      'Failure to Yield Right-of-Way: 206: 3.21%',
#      'PASSENGER VEHICLE: 2310: 36.01%',
#      'TAXI: 1202: 18.74%',
#      'SPORT UTILITY / STATION WAGON: 1059: 16.51%',
#      'VAN: 385: 6.0%',
#      'LARGE COM VEH(6 OR MORE TIRES): 227: 3.54%'),
#     (1,
#      'STREET CONDITION: 1: 100.0%',
#      '',
#      '',
#      'Cave-in: 1: 100.0%',
#      '',
#      '',
#      '',
#      '',
#      'NEW YORK')))),
#  (u'10465',
#   (16205539,
#    ((833,
#      1667,
#      251,
#      0,
#      '44: 18.0%',
#      '0: 0.0%',
#      '10: 4.0%',
#      '0: 0.0%',
#      '197: 78.0%',
#      '0: 0.0%',
#      'Driver Inattention/Distraction: 56: 3.36%',
#      'Failure to Yield Right-of-Way: 38: 2.28%',
#      'Backing Unsafely: 33: 1.98%',
#      'Prescription Medication: 22: 1.32%',
#      'Fatigued/Drowsy: 18: 1.08%',
#      'PASSENGER VEHICLE: 1095: 65.69%',
#      'SPORT UTILITY / STATION WAGON: 240: 14.4%',
#      'VAN: 29: 1.74%',
#      'OTHER: 29: 1.74%',
#      'LARGE COM VEH(6 OR MORE TIRES): 27: 1.62%'),
#     (1,
#      'STREET LIGHT CONDITION: 1: 100.0%',
#      '',
#      '',
#      'Street Light Out: 1: 100.0%',
#      '',
#      '',
#      '',
#      '',
#      'BRONX')))),
#  (u'10462',
#   (9360455,
#    ((1378,
#      2744,
#      367,
#      1,
#      '86: 23.0%',
#      '1: 100.0%',
#      '27: 7.0%',
#      '0: 0.0%',
#      '254: 69.0%',
#      '0: 0.0%',
#      'Driver Inattention/Distraction: 113: 4.12%',
#      'Failure to Yield Right-of-Way: 41: 1.49%',
#      'Other Vehicular: 37: 1.35%',
#      'Backing Unsafely: 34: 1.24%',
#      'Prescription Medication: 25: 0.91%',
#      'PASSENGER VEHICLE: 1614: 58.82%',
#      'SPORT UTILITY / STATION WAGON: 452: 16.47%',
#      'TAXI: 66: 2.41%',
#      'VAN: 64: 2.33%',
#      'OTHER: 52: 1.9%'),
#     (1,
#      'STREET LIGHT CONDITION: 1: 100.0%',
#      '',
#      '',
#      'Street Light Out: 1: 100.0%',
#      '',
#      '',
#      '',
#      '',
#      'BRONX')))),
#  (u'10463',
#   (24350341,
#    ((1163,
#      2291,
#      258,
#      1,
#      '70: 27.0%',
#      '0: 0.0%',
#      '11: 4.0%',
#      '0: 0.0%',
#      '177: 69.0%',
#      '1: 100.0%',
#      'Driver Inattention/Distraction: 142: 6.2%',
#      'Other Vehicular: 79: 3.45%',
#      'Backing Unsafely: 52: 2.27%',
#      'Failure to Yield Right-of-Way: 48: 2.1%',
#      'Fatigued/Drowsy: 43: 1.88%',
#      'PASSENGER VEHICLE: 1386: 60.5%',
#      'SPORT UTILITY / STATION WAGON: 395: 17.24%',
#      'OTHER: 53: 2.31%',
#      'BUS: 40: 1.75%',
#      'VAN: 37: 1.62%'),
#     (1,
#      'STREET CONDITION: 1: 100.0%',
#      '',
#      '',
#      'Cave-in: 1: 100.0%',
#      '',
#      '',
#      '',
#      '',
#      'BRONX')))),
#  (u'11422',
#   (55505561,
#    ((1295,
#      2639,
#      427,
#      5,
#      '35: 8.0%',
#      '2: 40.0%',
#      '8: 2.0%',
#      '0: 0.0%',
#      '384: 90.0%',
#      '3: 60.0%',
#      'Driver Inattention/Distraction: 108: 4.09%',
#      'Failure to Yield Right-of-Way: 88: 3.33%',
#      'Fatigued/Drowsy: 79: 2.99%',
#      'Turning Improperly: 25: 0.95%',
#      'Other Vehicular: 24: 0.91%',
#      'PASSENGER VEHICLE: 1644: 62.3%',
#      'SPORT UTILITY / STATION WAGON: 632: 23.95%',
#      'OTHER: 45: 1.71%',
#      'VAN: 41: 1.55%',
#      'PICK-UP TRUCK: 22: 0.83%'),
#     (1,
#      'STREET CONDITION: 1: 100.0%',
#      '',
#      '',
#      'Pothole: 1: 100.0%',
#      '',
#      '',
#      '',
#      '',
#      'Rosedale')))),
#  (u'11357',
#   (5986159,
#    ((646,
#      1341,
#      162,
#      0,
#      '21: 13.0%',
#      '0: 0.0%',
#      '8: 5.0%',
#      '0: 0.0%',
#      '133: 82.0%',
#      '0: 0.0%',
#      'Driver Inattention/Distraction: 49: 3.65%',
#      'Failure to Yield Right-of-Way: 29: 2.16%',
#      'Prescription Medication: 12: 0.89%',
#      'Fatigued/Drowsy: 11: 0.82%',
#      'Physical Disability: 9: 0.67%',
#      'PASSENGER VEHICLE: 894: 66.67%',
#      'SPORT UTILITY / STATION WAGON: 257: 19.16%',
#      'OTHER: 38: 2.83%',
#      'VAN: 16: 1.19%',
#      'SMALL COM VEH(4 TIRES): 15: 1.12%'),
#     (1,
#      'STREET CONDITION: 1: 100.0%',
#      '',
#      '',
#      'Pothole: 1: 100.0%',
#      '',
#      '',
#      '',
#      '',
#      'Whitestone')))),
#  (u'11210',
#   (8962791,
#    ((1652,
#      3342,
#      672,
#      2,
#      '140: 21.0%',
#      '2: 100.0%',
#      '47: 7.0%',
#      '0: 0.0%',
#      '485: 72.0%',
#      '0: 0.0%',
#      'Driver Inattention/Distraction: 87: 2.6%',
#      'Failure to Yield Right-of-Way: 74: 2.21%',
#      'Fatigued/Drowsy: 43: 1.29%',
#      'Prescription Medication: 30: 0.9%',
#      'Physical Disability: 27: 0.81%',
#      'PASSENGER VEHICLE: 1841: 55.09%',
#      'SPORT UTILITY / STATION WAGON: 852: 25.49%',
#      'VAN: 118: 3.53%',
#      'BUS: 87: 2.6%',
#      'BICYCLE: 52: 1.56%'),
#     (1,
#      'STREET CONDITION: 1: 100.0%',
#      '',
#      '',
#      'Pothole: 1: 100.0%',
#      '',
#      '',
#      '',
#      '',
#      'BROOKLYN')))),
#  (u'11216',
#   (55309653,
#    ((2012,
#      3964,
#      663,
#      1,
#      '165: 25.0%',
#      '0: 0.0%',
#      '93: 14.0%',
#      '0: 0.0%',
#      '405: 61.0%',
#      '1: 100.0%',
#      'Driver Inattention/Distraction: 136: 3.43%',
#      'Fatigued/Drowsy: 58: 1.46%',
#      'Failure to Yield Right-of-Way: 45: 1.14%',
#      'Lost Consciousness: 38: 0.96%',
#      'Outside Car Distraction: 30: 0.76%',
#      'PASSENGER VEHICLE: 2120: 53.48%',
#      'SPORT UTILITY / STATION WAGON: 845: 21.32%',
#      'VAN: 157: 3.96%',
#      'BICYCLE: 124: 3.13%',
#      'BUS: 68: 1.72%'),
#     (1,
#      'STREET CONDITION: 1: 100.0%',
#      '',
#      '',
#      'Failed Street Repair: 1: 100.0%',
#      '',
#      '',
#      '',
#      '',
#      'BROOKLYN')))),
#  (u'11215',
#   (24055017,
#    ((1958,
#      3868,
#      425,
#      0,
#      '108: 25.0%',
#      '0: 0.0%',
#      '93: 22.0%',
#      '0: 0.0%',
#      '224: 53.0%',
#      '0: 0.0%',
#      'Driver Inattention/Distraction: 204: 5.27%',
#      'Failure to Yield Right-of-Way: 80: 2.07%',
#      'Fatigued/Drowsy: 52: 1.34%',
#      'Backing Unsafely: 47: 1.22%',
#      'Lost Consciousness: 44: 1.14%',
#      'PASSENGER VEHICLE: 2165: 55.97%',
#      'SPORT UTILITY / STATION WAGON: 551: 14.25%',
#      'VAN: 174: 4.5%',
#      'OTHER: 152: 3.93%',
#      'BICYCLE: 114: 2.95%'),
#     (1,
#      'STREET CONDITION: 1: 100.0%',
#      '',
#      '',
#      'Pothole: 1: 100.0%',
#      '',
#      '',
#      '',
#      '',
#      'BROOKLYN')))),
#  (u'11219',
#   (4007342,
#    ((1759,
#      3477,
#      463,
#      3,
#      '167: 36.0%',
#      '1: 33.0%',
#      '63: 14.0%',
#      '1: 33.0%',
#      '233: 50.0%',
#      '1: 33.0%',
#      'Driver Inattention/Distraction: 226: 6.5%',
#      'Failure to Yield Right-of-Way: 102: 2.93%',
#      'Backing Unsafely: 48: 1.38%',
#      'Fatigued/Drowsy: 47: 1.35%',
#      'Other Vehicular: 33: 0.95%',
#      'PASSENGER VEHICLE: 1573: 45.24%',
#      'SPORT UTILITY / STATION WAGON: 1155: 33.22%',
#      'VAN: 107: 3.08%',
#      'BUS: 83: 2.39%',
#      'LARGE COM VEH(6 OR MORE TIRES): 74: 2.13%'),
#     (1,
#      'STREET LIGHT CONDITION: 1: 100.0%',
#      '',
#      '',
#      'Street Light Out: 1: 100.0%',
#      '',
#      '',
#      '',
#      '',
#      'BROOKLYN'))))]

# %%
def mapper(tuples):
    for t in tuples:
        zip_code = t[0]
        traffic_count = t[1][0]
        acc_t = t[1][1][0]
        three_t = t[1][1][1]
        tuple_type = type(())
        #yield zip_code, traffic_count, acc_t, three_t
#         zip_code = t[0]
#         acc_t = t[1][0]
#         three_t = t[1][1]
#         tuple_type = type(())
        if type(three_t) != tuple_type  or type(acc_t) != tuple_type:
            continue
        # accident dataset
        t_accidents  = acc_t[0]
        t_vehicles   = acc_t[1]
        t_per_i      = acc_t[2]
        t_per_k      = acc_t[3]
        t_ped_i      = acc_t[4]
        t_ped_k      = acc_t[5]
        t_cyc_i      = acc_t[6]
        t_cyc_k      = acc_t[7]
        t_mot_i      = acc_t[8]
        t_mot_k      = acc_t[9]
        fac1         = acc_t[10]
        fac2         = acc_t[11]
        fac3         = acc_t[12]
        fac4         = acc_t[13]
        fac5         = acc_t[14]
        veh1         = acc_t[15]
        veh2         = acc_t[16]
        veh3         = acc_t[17]
        veh4         = acc_t[18]
        veh5         = acc_t[19]
        # 311 dataset
        t_complaints = three_t[0]
        comp1        = three_t[1]
        comp2        = three_t[2]
        comp3        = three_t[3]
        desc1        = three_t[4]
        desc2        = three_t[5]
        desc3        = three_t[6]
        desc4        = three_t[7]
        desc5        = three_t[8]
        city         = three_t[9]
        
        accidents_per_1000_vehicle = round(t_accidents / float(traffic_count) * 1000, 2)
        injuries_per_1000_accident = round(t_per_i / float(t_accidents) * 1000, 2)
        deaths_per_1000_accident   = round(t_per_k / float(t_accidents) * 1000, 2)
        vehicles_involved_per_accident = round(t_vehicles / float(t_accidents), 2)
        yield (city, zip_code, accidents_per_1000_vehicle, injuries_per_1000_accident, deaths_per_1000_accident, vehicles_involved_per_accident,
              t_accidents, t_vehicles, fac1, fac2, fac3, fac4, fac5, veh1, veh2, veh3, veh4, veh5,
              comp1, comp2, comp3, desc1, desc2, desc3, desc4, desc5, t_complaints)

# %%
full_rdd = joined_rdd.mapPartitions(mapper)
full_rdd.collect()
# Out:
# [('STATEN ISLAND',
#   u'10314',
#   0.11,
#   239.88,
#   1.74,
#   1.99,
#   2297,
#   4582,
#   'Driver Inattention/Distraction: 281: 6.13%',
#   'Fatigued/Drowsy: 154: 3.36%',
#   'Failure to Yield Right-of-Way: 92: 2.01%',
#   'Pavement Slippery: 70: 1.53%',
#   'Other Vehicular: 52: 1.13%',
#   'PASSENGER VEHICLE: 3124: 68.18%',
#   'SPORT UTILITY / STATION WAGON: 950: 20.73%',
#   'OTHER: 75: 1.64%',
#   'PICK-UP TRUCK: 56: 1.22%',
#   'VAN: 53: 1.16%',
#   'STREET LIGHT CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Street Light Out: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BROOKLYN',
#   u'11232',
#   0.21,
#   228.72,
#   0.0,
#   1.99,
#   1351,
#   2684,
#   'Driver Inattention/Distraction: 195: 7.27%',
#   'Failure to Yield Right-of-Way: 82: 3.06%',
#   'Backing Unsafely: 80: 2.98%',
#   'Fatigued/Drowsy: 62: 2.31%',
#   'Driver Inexperience: 50: 1.86%',
#   'PASSENGER VEHICLE: 1652: 61.55%',
#   'SPORT UTILITY / STATION WAGON: 309: 11.51%',
#   'SMALL COM VEH(4 TIRES): 115: 4.28%',
#   'VAN: 109: 4.06%',
#   'LARGE COM VEH(6 OR MORE TIRES): 107: 3.99%',
#   'STREET LIGHT CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Street Light Dayburning: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BROOKLYN',
#   u'11233',
#   0.25,
#   421.43,
#   0.96,
#   1.98,
#   2081,
#   4116,
#   'Driver Inattention/Distraction: 182: 4.42%',
#   'Fatigued/Drowsy: 64: 1.55%',
#   'Failure to Yield Right-of-Way: 59: 1.43%',
#   'Turning Improperly: 31: 0.75%',
#   'Prescription Medication: 30: 0.73%',
#   'PASSENGER VEHICLE: 2470: 60.01%',
#   'SPORT UTILITY / STATION WAGON: 823: 20.0%',
#   'VAN: 88: 2.14%',
#   'OTHER: 78: 1.9%',
#   'BICYCLE: 73: 1.77%',
#   'STREET LIGHT CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Street Light Out: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('NEW YORK',
#   u'10003',
#   0.18,
#   210.72,
#   0.92,
#   1.92,
#   2164,
#   4155,
#   'Driver Inattention/Distraction: 225: 5.42%',
#   'Fatigued/Drowsy: 79: 1.9%',
#   'Lost Consciousness: 67: 1.61%',
#   'Backing Unsafely: 61: 1.47%',
#   'Failure to Yield Right-of-Way: 58: 1.4%',
#   'PASSENGER VEHICLE: 1621: 39.01%',
#   'TAXI: 855: 20.58%',
#   'SPORT UTILITY / STATION WAGON: 475: 11.43%',
#   'VAN: 200: 4.81%',
#   'BICYCLE: 154: 3.71%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Pothole: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('Oakland Gardens',
#   u'11364',
#   0.06,
#   236.84,
#   6.19,
#   1.99,
#   646,
#   1283,
#   'Driver Inattention/Distraction: 122: 9.51%',
#   'Failure to Yield Right-of-Way: 111: 8.65%',
#   'Fatigued/Drowsy: 65: 5.07%',
#   'Backing Unsafely: 54: 4.21%',
#   'Prescription Medication: 30: 2.34%',
#   'PASSENGER VEHICLE: 744: 57.99%',
#   'SPORT UTILITY / STATION WAGON: 369: 28.76%',
#   'VAN: 31: 2.42%',
#   'BUS: 16: 1.25%',
#   'OTHER: 15: 1.17%',
#   'STREET LIGHT CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Street Light Out: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BROOKLYN',
#   u'11207',
#   0.26,
#   427.16,
#   0.99,
#   2.0,
#   4050,
#   8088,
#   'Driver Inattention/Distraction: 127: 1.57%',
#   'Failure to Yield Right-of-Way: 59: 0.73%',
#   'Other Vehicular: 50: 0.62%',
#   'Fatigued/Drowsy: 42: 0.52%',
#   'Backing Unsafely: 26: 0.32%',
#   'PASSENGER VEHICLE: 5041: 62.33%',
#   'SPORT UTILITY / STATION WAGON: 1297: 16.04%',
#   'OTHER: 374: 4.62%',
#   'VAN: 192: 2.37%',
#   'BICYCLE: 119: 1.47%',
#   'STREET LIGHT CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Street Light Dayburning: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BROOKLYN',
#   u'11208',
#   0.05,
#   398.75,
#   2.24,
#   1.99,
#   2232,
#   4438,
#   'Driver Inattention/Distraction: 88: 1.98%',
#   'Failure to Yield Right-of-Way: 39: 0.88%',
#   'Other Vehicular: 34: 0.77%',
#   'Physical Disability: 18: 0.41%',
#   'Traffic Control Disregarded: 17: 0.38%',
#   'PASSENGER VEHICLE: 2781: 62.66%',
#   'SPORT UTILITY / STATION WAGON: 698: 15.73%',
#   'VAN: 91: 2.05%',
#   'OTHER: 82: 1.85%',
#   'PICK-UP TRUCK: 64: 1.44%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Pothole: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BROOKLYN',
#   u'11226',
#   0.19,
#   409.5,
#   0.81,
#   1.98,
#   2464,
#   4874,
#   'Driver Inattention/Distraction: 154: 3.16%',
#   'Fatigued/Drowsy: 69: 1.42%',
#   'Failure to Yield Right-of-Way: 61: 1.25%',
#   'Other Vehicular: 51: 1.05%',
#   'Backing Unsafely: 40: 0.82%',
#   'PASSENGER VEHICLE: 2543: 52.17%',
#   'SPORT UTILITY / STATION WAGON: 1229: 25.22%',
#   'VAN: 200: 4.1%',
#   'BICYCLE: 113: 2.32%',
#   'BUS: 94: 1.93%',
#   'STREET SIGN - DAMAGED: 1: 100.0%',
#   '',
#   '',
#   'Street Cleaning - ASP: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('NEW YORK',
#   u'10032',
#   0.13,
#   302.47,
#   0.88,
#   1.93,
#   1134,
#   2193,
#   'Driver Inattention/Distraction: 67: 3.06%',
#   'Other Vehicular: 41: 1.87%',
#   'Failure to Yield Right-of-Way: 32: 1.46%',
#   'Fatigued/Drowsy: 23: 1.05%',
#   'Backing Unsafely: 22: 1.0%',
#   'PASSENGER VEHICLE: 1051: 47.93%',
#   'SPORT UTILITY / STATION WAGON: 439: 20.02%',
#   'OTHER: 140: 6.38%',
#   'VAN: 101: 4.61%',
#   'TAXI: 87: 3.97%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Pothole: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('NEW YORK',
#   u'10019',
#   0.17,
#   143.33,
#   0.91,
#   1.94,
#   3307,
#   6415,
#   'Driver Inattention/Distraction: 1051: 16.38%',
#   'Fatigued/Drowsy: 427: 6.66%',
#   'Turning Improperly: 369: 5.75%',
#   'Lost Consciousness: 314: 4.89%',
#   'Failure to Yield Right-of-Way: 206: 3.21%',
#   'PASSENGER VEHICLE: 2310: 36.01%',
#   'TAXI: 1202: 18.74%',
#   'SPORT UTILITY / STATION WAGON: 1059: 16.51%',
#   'VAN: 385: 6.0%',
#   'LARGE COM VEH(6 OR MORE TIRES): 227: 3.54%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Cave-in: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BRONX',
#   u'10465',
#   0.05,
#   301.32,
#   0.0,
#   2.0,
#   833,
#   1667,
#   'Driver Inattention/Distraction: 56: 3.36%',
#   'Failure to Yield Right-of-Way: 38: 2.28%',
#   'Backing Unsafely: 33: 1.98%',
#   'Prescription Medication: 22: 1.32%',
#   'Fatigued/Drowsy: 18: 1.08%',
#   'PASSENGER VEHICLE: 1095: 65.69%',
#   'SPORT UTILITY / STATION WAGON: 240: 14.4%',
#   'VAN: 29: 1.74%',
#   'OTHER: 29: 1.74%',
#   'LARGE COM VEH(6 OR MORE TIRES): 27: 1.62%',
#   'STREET LIGHT CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Street Light Out: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BRONX',
#   u'10462',
#   0.15,
#   266.33,
#   0.73,
#   1.99,
#   1378,
#   2744,
#   'Driver Inattention/Distraction: 113: 4.12%',
#   'Failure to Yield Right-of-Way: 41: 1.49%',
#   'Other Vehicular: 37: 1.35%',
#   'Backing Unsafely: 34: 1.24%',
#   'Prescription Medication: 25: 0.91%',
#   'PASSENGER VEHICLE: 1614: 58.82%',
#   'SPORT UTILITY / STATION WAGON: 452: 16.47%',
#   'TAXI: 66: 2.41%',
#   'VAN: 64: 2.33%',
#   'OTHER: 52: 1.9%',
#   'STREET LIGHT CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Street Light Out: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BRONX',
#   u'10463',
#   0.05,
#   221.84,
#   0.86,
#   1.97,
#   1163,
#   2291,
#   'Driver Inattention/Distraction: 142: 6.2%',
#   'Other Vehicular: 79: 3.45%',
#   'Backing Unsafely: 52: 2.27%',
#   'Failure to Yield Right-of-Way: 48: 2.1%',
#   'Fatigued/Drowsy: 43: 1.88%',
#   'PASSENGER VEHICLE: 1386: 60.5%',
#   'SPORT UTILITY / STATION WAGON: 395: 17.24%',
#   'OTHER: 53: 2.31%',
#   'BUS: 40: 1.75%',
#   'VAN: 37: 1.62%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Cave-in: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('Rosedale',
#   u'11422',
#   0.02,
#   329.73,
#   3.86,
#   2.04,
#   1295,
#   2639,
#   'Driver Inattention/Distraction: 108: 4.09%',
#   'Failure to Yield Right-of-Way: 88: 3.33%',
#   'Fatigued/Drowsy: 79: 2.99%',
#   'Turning Improperly: 25: 0.95%',
#   'Other Vehicular: 24: 0.91%',
#   'PASSENGER VEHICLE: 1644: 62.3%',
#   'SPORT UTILITY / STATION WAGON: 632: 23.95%',
#   'OTHER: 45: 1.71%',
#   'VAN: 41: 1.55%',
#   'PICK-UP TRUCK: 22: 0.83%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Pothole: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('Whitestone',
#   u'11357',
#   0.11,
#   250.77,
#   0.0,
#   2.08,
#   646,
#   1341,
#   'Driver Inattention/Distraction: 49: 3.65%',
#   'Failure to Yield Right-of-Way: 29: 2.16%',
#   'Prescription Medication: 12: 0.89%',
#   'Fatigued/Drowsy: 11: 0.82%',
#   'Physical Disability: 9: 0.67%',
#   'PASSENGER VEHICLE: 894: 66.67%',
#   'SPORT UTILITY / STATION WAGON: 257: 19.16%',
#   'OTHER: 38: 2.83%',
#   'VAN: 16: 1.19%',
#   'SMALL COM VEH(4 TIRES): 15: 1.12%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Pothole: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BROOKLYN',
#   u'11210',
#   0.18,
#   406.78,
#   1.21,
#   2.02,
#   1652,
#   3342,
#   'Driver Inattention/Distraction: 87: 2.6%',
#   'Failure to Yield Right-of-Way: 74: 2.21%',
#   'Fatigued/Drowsy: 43: 1.29%',
#   'Prescription Medication: 30: 0.9%',
#   'Physical Disability: 27: 0.81%',
#   'PASSENGER VEHICLE: 1841: 55.09%',
#   'SPORT UTILITY / STATION WAGON: 852: 25.49%',
#   'VAN: 118: 3.53%',
#   'BUS: 87: 2.6%',
#   'BICYCLE: 52: 1.56%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Pothole: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BROOKLYN',
#   u'11216',
#   0.04,
#   329.52,
#   0.5,
#   1.97,
#   2012,
#   3964,
#   'Driver Inattention/Distraction: 136: 3.43%',
#   'Fatigued/Drowsy: 58: 1.46%',
#   'Failure to Yield Right-of-Way: 45: 1.14%',
#   'Lost Consciousness: 38: 0.96%',
#   'Outside Car Distraction: 30: 0.76%',
#   'PASSENGER VEHICLE: 2120: 53.48%',
#   'SPORT UTILITY / STATION WAGON: 845: 21.32%',
#   'VAN: 157: 3.96%',
#   'BICYCLE: 124: 3.13%',
#   'BUS: 68: 1.72%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Failed Street Repair: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BROOKLYN',
#   u'11215',
#   0.08,
#   217.06,
#   0.0,
#   1.98,
#   1958,
#   3868,
#   'Driver Inattention/Distraction: 204: 5.27%',
#   'Failure to Yield Right-of-Way: 80: 2.07%',
#   'Fatigued/Drowsy: 52: 1.34%',
#   'Backing Unsafely: 47: 1.22%',
#   'Lost Consciousness: 44: 1.14%',
#   'PASSENGER VEHICLE: 2165: 55.97%',
#   'SPORT UTILITY / STATION WAGON: 551: 14.25%',
#   'VAN: 174: 4.5%',
#   'OTHER: 152: 3.93%',
#   'BICYCLE: 114: 2.95%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Pothole: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BROOKLYN',
#   u'11219',
#   0.44,
#   263.22,
#   1.71,
#   1.98,
#   1759,
#   3477,
#   'Driver Inattention/Distraction: 226: 6.5%',
#   'Failure to Yield Right-of-Way: 102: 2.93%',
#   'Backing Unsafely: 48: 1.38%',
#   'Fatigued/Drowsy: 47: 1.35%',
#   'Other Vehicular: 33: 0.95%',
#   'PASSENGER VEHICLE: 1573: 45.24%',
#   'SPORT UTILITY / STATION WAGON: 1155: 33.22%',
#   'VAN: 107: 3.08%',
#   'BUS: 83: 2.39%',
#   'LARGE COM VEH(6 OR MORE TIRES): 74: 2.13%',
#   'STREET LIGHT CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Street Light Out: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1)]

# %%
from pyspark.sql.types import *
fields = [StructField("", StringType(), True) for _ in range(0, 27)]
fields[0].name = "City"

fields[1].name = "Zip_Code"

fields[2].dataType = FloatType()
fields[2].name = "Accidents_Per_1000_Vehicles"

fields[3].dataType = FloatType()
fields[3].name = "Injuries_Per_1000_Accidents"

fields[4].dataType = FloatType()
fields[4].name = "Deaths_Per_1000_Accidents"

fields[5].dataType = FloatType()
fields[5].name = "Vehicles_Involved_Per_Accident"

fields[6].dataType = IntegerType()
fields[6].name = "Total_Number_of_Accidents"

fields[7].dataType = IntegerType()
fields[7].name = "Total_Number_of_Vehicles_Involved_in_Accidents"

fields[8].name  = "Top_Factor_1"
fields[9].name  = "Top_Factor_2"
fields[10].name  = "Top_Factor_3"
fields[11].name = "Top_Factor_4"
fields[12].name = "Top_Factor_5"

fields[13].name = "Most_Common_Vehicle_Type_1"
fields[14].name = "Most_Common_Vehicle_Type_2"
fields[15].name = "Most_Common_Vehicle_Type_3"
fields[16].name = "Most_Common_Vehicle_Type_4"
fields[17].name = "Most_Common_Vehicle_Type_5"

fields[18].name = "Top_Street_Complaint_1"
fields[19].name = "Top_Street_Complaint_2"
fields[20].name = "Top_Street_Complaint_3"

fields[21].name = "Top_Complaint_Description_1"
fields[22].name = "Top_Complaint_Description_2"
fields[23].name = "Top_Complaint_Description_3"
fields[24].name = "Top_Complaint_Description_4"
fields[25].name = "Top_Complaint_Description_5"

fields[26].dataType = IntegerType()
fields[26].name = "Total Street Complaints"

schema = StructType(fields)

# %%
full_df = sqlContext.createDataFrame(full_rdd, schema)
full_df.collect()
# Out:
# [Row(City=u'STATEN ISLAND', Zip_Code=u'10314', Accidents_Per_1000_Vehicles=0.10999999940395355, Injuries_Per_1000_Accidents=239.8800048828125, Deaths_Per_1000_Accidents=1.7400000095367432, Vehicles_Involved_Per_Accident=1.9900000095367432, =2297, Total_Number_of_Vehicles_Involved_in_Accidents=4582, Top_Factor_1=u'Driver Inattention/Distraction: 281: 6.13%', Top_Factor_2=u'Fatigued/Drowsy: 154: 3.36%', Top_Factor_3=u'Failure to Yield Right-of-Way: 92: 2.01%', Top_Factor_4=u'Pavement Slippery: 70: 1.53%', Top_Factor_5=u'Other Vehicular: 52: 1.13%', Most_Common_Vehicle_Type_1=u'PASSENGER VEHICLE: 3124: 68.18%', Most_Common_Vehicle_Type_2=u'SPORT UTILITY / STATION WAGON: 950: 20.73%', Most_Common_Vehicle_Type_3=u'OTHER: 75: 1.64%', Most_Common_Vehicle_Type_4=u'PICK-UP TRUCK: 56: 1.22%', Most_Common_Vehicle_Type_5=u'VAN: 53: 1.16%', Top_Street_Complaint_1=u'STREET LIGHT CONDITION: 1: 100.0%', Top_Street_Complaint_2=u'', Top_Street_Complaint_3=u'', Top_Complaint_Description_1=u'Street Light Out: 1: 100.0%', Top_Complaint_Description_2=u'', Top_Complaint_Description_3=u'', Top_Complaint_Description_4=u'', Top_Complaint_Description_5=u'', Total Street Complaints=1),
#  Row(City=u'BROOKLYN', Zip_Code=u'11232', Accidents_Per_1000_Vehicles=0.20999999344348907, Injuries_Per_1000_Accidents=228.72000122070312, Deaths_Per_1000_Accidents=0.0, Vehicles_Involved_Per_Accident=1.9900000095367432, =1351, Total_Number_of_Vehicles_Involved_in_Accidents=2684, Top_Factor_1=u'Driver Inattention/Distraction: 195: 7.27%', Top_Factor_2=u'Failure to Yield Right-of-Way: 82: 3.06%', Top_Factor_3=u'Backing Unsafely: 80: 2.98%', Top_Factor_4=u'Fatigued/Drowsy: 62: 2.31%', Top_Factor_5=u'Driver Inexperience: 50: 1.86%', Most_Common_Vehicle_Type_1=u'PASSENGER VEHICLE: 1652: 61.55%', Most_Common_Vehicle_Type_2=u'SPORT UTILITY / STATION WAGON: 309: 11.51%', Most_Common_Vehicle_Type_3=u'SMALL COM VEH(4 TIRES): 115: 4.28%', Most_Common_Vehicle_Type_4=u'VAN: 109: 4.06%', Most_Common_Vehicle_Type_5=u'LARGE COM VEH(6 OR MORE TIRES): 107: 3.99%', Top_Street_Complaint_1=u'STREET LIGHT CONDITION: 1: 100.0%', Top_Street_Complaint_2=u'', Top_Street_Complaint_3=u'', Top_Complaint_Description_1=u'Street Light Dayburning: 1: 100.0%', Top_Complaint_Description_2=u'', Top_Complaint_Description_3=u'', Top_Complaint_Description_4=u'', Top_Complaint_Description_5=u'', Total Street Complaints=1),
#  Row(City=u'BROOKLYN', Zip_Code=u'11233', Accidents_Per_1000_Vehicles=0.25, Injuries_Per_1000_Accidents=421.42999267578125, Deaths_Per_1000_Accidents=0.9599999785423279, Vehicles_Involved_Per_Accident=1.9800000190734863, =2081, Total_Number_of_Vehicles_Involved_in_Accidents=4116, Top_Factor_1=u'Driver Inattention/Distraction: 182: 4.42%', Top_Factor_2=u'Fatigued/Drowsy: 64: 1.55%', Top_Factor_3=u'Failure to Yield Right-of-Way: 59: 1.43%', Top_Factor_4=u'Turning Improperly: 31: 0.75%', Top_Factor_5=u'Prescription Medication: 30: 0.73%', Most_Common_Vehicle_Type_1=u'PASSENGER VEHICLE: 2470: 60.01%', Most_Common_Vehicle_Type_2=u'SPORT UTILITY / STATION WAGON: 823: 20.0%', Most_Common_Vehicle_Type_3=u'VAN: 88: 2.14%', Most_Common_Vehicle_Type_4=u'OTHER: 78: 1.9%', Most_Common_Vehicle_Type_5=u'BICYCLE: 73: 1.77%', Top_Street_Complaint_1=u'STREET LIGHT CONDITION: 1: 100.0%', Top_Street_Complaint_2=u'', Top_Street_Complaint_3=u'', Top_Complaint_Description_1=u'Street Light Out: 1: 100.0%', Top_Complaint_Description_2=u'', Top_Complaint_Description_3=u'', Top_Complaint_Description_4=u'', Top_Complaint_Description_5=u'', Total Street Complaints=1),
#  Row(City=u'NEW YORK', Zip_Code=u'10003', Accidents_Per_1000_Vehicles=0.18000000715255737, Injuries_Per_1000_Accidents=210.72000122070312, Deaths_Per_1000_Accidents=0.9200000166893005, Vehicles_Involved_Per_Accident=1.9199999570846558, =2164, Total_Number_of_Vehicles_Involved_in_Accidents=4155, Top_Factor_1=u'Driver Inattention/Distraction: 225: 5.42%', Top_Factor_2=u'Fatigued/Drowsy: 79: 1.9%', Top_Factor_3=u'Lost Consciousness: 67: 1.61%', Top_Factor_4=u'Backing Unsafely: 61: 1.47%', Top_Factor_5=u'Failure to Yield Right-of-Way: 58: 1.4%', Most_Common_Vehicle_Type_1=u'PASSENGER VEHICLE: 1621: 39.01%', Most_Common_Vehicle_Type_2=u'TAXI: 855: 20.58%', Most_Common_Vehicle_Type_3=u'SPORT UTILITY / STATION WAGON: 475: 11.43%', Most_Common_Vehicle_Type_4=u'VAN: 200: 4.81%', Most_Common_Vehicle_Type_5=u'BICYCLE: 154: 3.71%', Top_Street_Complaint_1=u'STREET CONDITION: 1: 100.0%', Top_Street_Complaint_2=u'', Top_Street_Complaint_3=u'', Top_Complaint_Description_1=u'Pothole: 1: 100.0%', Top_Complaint_Description_2=u'', Top_Complaint_Description_3=u'', Top_Complaint_Description_4=u'', Top_Complaint_Description_5=u'', Total Street Complaints=1),
#  Row(City=u'Oakland Gardens', Zip_Code=u'11364', Accidents_Per_1000_Vehicles=0.05999999865889549, Injuries_Per_1000_Accidents=236.83999633789062, Deaths_Per_1000_Accidents=6.190000057220459, Vehicles_Involved_Per_Accident=1.9900000095367432, =646, Total_Number_of_Vehicles_Involved_in_Accidents=1283, Top_Factor_1=u'Driver Inattention/Distraction: 122: 9.51%', Top_Factor_2=u'Failure to Yield Right-of-Way: 111: 8.65%', Top_Factor_3=u'Fatigued/Drowsy: 65: 5.07%', Top_Factor_4=u'Backing Unsafely: 54: 4.21%', Top_Factor_5=u'Prescription Medication: 30: 2.34%', Most_Common_Vehicle_Type_1=u'PASSENGER VEHICLE: 744: 57.99%', Most_Common_Vehicle_Type_2=u'SPORT UTILITY / STATION WAGON: 369: 28.76%', Most_Common_Vehicle_Type_3=u'VAN: 31: 2.42%', Most_Common_Vehicle_Type_4=u'BUS: 16: 1.25%', Most_Common_Vehicle_Type_5=u'OTHER: 15: 1.17%', Top_Street_Complaint_1=u'STREET LIGHT CONDITION: 1: 100.0%', Top_Street_Complaint_2=u'', Top_Street_Complaint_3=u'', Top_Complaint_Description_1=u'Street Light Out: 1: 100.0%', Top_Complaint_Description_2=u'', Top_Complaint_Description_3=u'', Top_Complaint_Description_4=u'', Top_Complaint_Description_5=u'', Total Street Complaints=1),
#  Row(City=u'BROOKLYN', Zip_Code=u'11207', Accidents_Per_1000_Vehicles=0.25999999046325684, Injuries_Per_1000_Accidents=427.1600036621094, Deaths_Per_1000_Accidents=0.9900000095367432, Vehicles_Involved_Per_Accident=2.0, =4050, Total_Number_of_Vehicles_Involved_in_Accidents=8088, Top_Factor_1=u'Driver Inattention/Distraction: 127: 1.57%', Top_Factor_2=u'Failure to Yield Right-of-Way: 59: 0.73%', Top_Factor_3=u'Other Vehicular: 50: 0.62%', Top_Factor_4=u'Fatigued/Drowsy: 42: 0.52%', Top_Factor_5=u'Backing Unsafely: 26: 0.32%', Most_Common_Vehicle_Type_1=u'PASSENGER VEHICLE: 5041: 62.33%', Most_Common_Vehicle_Type_2=u'SPORT UTILITY / STATION WAGON: 1297: 16.04%', Most_Common_Vehicle_Type_3=u'OTHER: 374: 4.62%', Most_Common_Vehicle_Type_4=u'VAN: 192: 2.37%', Most_Common_Vehicle_Type_5=u'BICYCLE: 119: 1.47%', Top_Street_Complaint_1=u'STREET LIGHT CONDITION: 1: 100.0%', Top_Street_Complaint_2=u'', Top_Street_Complaint_3=u'', Top_Complaint_Description_1=u'Street Light Dayburning: 1: 100.0%', Top_Complaint_Description_2=u'', Top_Complaint_Description_3=u'', Top_Complaint_Description_4=u'', Top_Complaint_Description_5=u'', Total Street Complaints=1),
#  Row(City=u'BROOKLYN', Zip_Code=u'11208', Accidents_Per_1000_Vehicles=0.05000000074505806, Injuries_Per_1000_Accidents=398.75, Deaths_Per_1000_Accidents=2.240000009536743, Vehicles_Involved_Per_Accident=1.9900000095367432, =2232, Total_Number_of_Vehicles_Involved_in_Accidents=4438, Top_Factor_1=u'Driver Inattention/Distraction: 88: 1.98%', Top_Factor_2=u'Failure to Yield Right-of-Way: 39: 0.88%', Top_Factor_3=u'Other Vehicular: 34: 0.77%', Top_Factor_4=u'Physical Disability: 18: 0.41%', Top_Factor_5=u'Traffic Control Disregarded: 17: 0.38%', Most_Common_Vehicle_Type_1=u'PASSENGER VEHICLE: 2781: 62.66%', Most_Common_Vehicle_Type_2=u'SPORT UTILITY / STATION WAGON: 698: 15.73%', Most_Common_Vehicle_Type_3=u'VAN: 91: 2.05%', Most_Common_Vehicle_Type_4=u'OTHER: 82: 1.85%', Most_Common_Vehicle_Type_5=u'PICK-UP TRUCK: 64: 1.44%', Top_Street_Complaint_1=u'STREET CONDITION: 1: 100.0%', Top_Street_Complaint_2=u'', Top_Street_Complaint_3=u'', Top_Complaint_Description_1=u'Pothole: 1: 100.0%', Top_Complaint_Description_2=u'', Top_Complaint_Description_3=u'', Top_Complaint_Description_4=u'', Top_Complaint_Description_5=u'', Total Street Complaints=1),
#  Row(City=u'BROOKLYN', Zip_Code=u'11226', Accidents_Per_1000_Vehicles=0.1899999976158142, Injuries_Per_1000_Accidents=409.5, Deaths_Per_1000_Accidents=0.8100000023841858, Vehicles_Involved_Per_Accident=1.9800000190734863, =2464, Total_Number_of_Vehicles_Involved_in_Accidents=4874, Top_Factor_1=u'Driver Inattention/Distraction: 154: 3.16%', Top_Factor_2=u'Fatigued/Drowsy: 69: 1.42%', Top_Factor_3=u'Failure to Yield Right-of-Way: 61: 1.25%', Top_Factor_4=u'Other Vehicular: 51: 1.05%', Top_Factor_5=u'Backing Unsafely: 40: 0.82%', Most_Common_Vehicle_Type_1=u'PASSENGER VEHICLE: 2543: 52.17%', Most_Common_Vehicle_Type_2=u'SPORT UTILITY / STATION WAGON: 1229: 25.22%', Most_Common_Vehicle_Type_3=u'VAN: 200: 4.1%', Most_Common_Vehicle_Type_4=u'BICYCLE: 113: 2.32%', Most_Common_Vehicle_Type_5=u'BUS: 94: 1.93%', Top_Street_Complaint_1=u'STREET SIGN - DAMAGED: 1: 100.0%', Top_Street_Complaint_2=u'', Top_Street_Complaint_3=u'', Top_Complaint_Description_1=u'Street Cleaning - ASP: 1: 100.0%', Top_Complaint_Description_2=u'', Top_Complaint_Description_3=u'', Top_Complaint_Description_4=u'', Top_Complaint_Description_5=u'', Total Street Complaints=1),
#  Row(City=u'NEW YORK', Zip_Code=u'10032', Accidents_Per_1000_Vehicles=0.12999999523162842, Injuries_Per_1000_Accidents=302.4700012207031, Deaths_Per_1000_Accidents=0.8799999952316284, Vehicles_Involved_Per_Accident=1.9299999475479126, =1134, Total_Number_of_Vehicles_Involved_in_Accidents=2193, Top_Factor_1=u'Driver Inattention/Distraction: 67: 3.06%', Top_Factor_2=u'Other Vehicular: 41: 1.87%', Top_Factor_3=u'Failure to Yield Right-of-Way: 32: 1.46%', Top_Factor_4=u'Fatigued/Drowsy: 23: 1.05%', Top_Factor_5=u'Backing Unsafely: 22: 1.0%', Most_Common_Vehicle_Type_1=u'PASSENGER VEHICLE: 1051: 47.93%', Most_Common_Vehicle_Type_2=u'SPORT UTILITY / STATION WAGON: 439: 20.02%', Most_Common_Vehicle_Type_3=u'OTHER: 140: 6.38%', Most_Common_Vehicle_Type_4=u'VAN: 101: 4.61%', Most_Common_Vehicle_Type_5=u'TAXI: 87: 3.97%', Top_Street_Complaint_1=u'STREET CONDITION: 1: 100.0%', Top_Street_Complaint_2=u'', Top_Street_Complaint_3=u'', Top_Complaint_Description_1=u'Pothole: 1: 100.0%', Top_Complaint_Description_2=u'', Top_Complaint_Description_3=u'', Top_Complaint_Description_4=u'', Top_Complaint_Description_5=u'', Total Street Complaints=1),
#  Row(City=u'NEW YORK', Zip_Code=u'10019', Accidents_Per_1000_Vehicles=0.17000000178813934, Injuries_Per_1000_Accidents=143.3300018310547, Deaths_Per_1000_Accidents=0.9100000262260437, Vehicles_Involved_Per_Accident=1.940000057220459, =3307, Total_Number_of_Vehicles_Involved_in_Accidents=6415, Top_Factor_1=u'Driver Inattention/Distraction: 1051: 16.38%', Top_Factor_2=u'Fatigued/Drowsy: 427: 6.66%', Top_Factor_3=u'Turning Improperly: 369: 5.75%', Top_Factor_4=u'Lost Consciousness: 314: 4.89%', Top_Factor_5=u'Failure to Yield Right-of-Way: 206: 3.21%', Most_Common_Vehicle_Type_1=u'PASSENGER VEHICLE: 2310: 36.01%', Most_Common_Vehicle_Type_2=u'TAXI: 1202: 18.74%', Most_Common_Vehicle_Type_3=u'SPORT UTILITY / STATION WAGON: 1059: 16.51%', Most_Common_Vehicle_Type_4=u'VAN: 385: 6.0%', Most_Common_Vehicle_Type_5=u'LARGE COM VEH(6 OR MORE TIRES): 227: 3.54%', Top_Street_Complaint_1=u'STREET CONDITION: 1: 100.0%', Top_Street_Complaint_2=u'', Top_Street_Complaint_3=u'', Top_Complaint_Description_1=u'Cave-in: 1: 100.0%', Top_Complaint_Description_2=u'', Top_Complaint_Description_3=u'', Top_Complaint_Description_4=u'', Top_Complaint_Description_5=u'', Total Street Complaints=1),
#  Row(City=u'BRONX', Zip_Code=u'10465', Accidents_Per_1000_Vehicles=0.05000000074505806, Injuries_Per_1000_Accidents=301.32000732421875, Deaths_Per_1000_Accidents=0.0, Vehicles_Involved_Per_Accident=2.0, =833, Total_Number_of_Vehicles_Involved_in_Accidents=1667, Top_Factor_1=u'Driver Inattention/Distraction: 56: 3.36%', Top_Factor_2=u'Failure to Yield Right-of-Way: 38: 2.28%', Top_Factor_3=u'Backing Unsafely: 33: 1.98%', Top_Factor_4=u'Prescription Medication: 22: 1.32%', Top_Factor_5=u'Fatigued/Drowsy: 18: 1.08%', Most_Common_Vehicle_Type_1=u'PASSENGER VEHICLE: 1095: 65.69%', Most_Common_Vehicle_Type_2=u'SPORT UTILITY / STATION WAGON: 240: 14.4%', Most_Common_Vehicle_Type_3=u'VAN: 29: 1.74%', Most_Common_Vehicle_Type_4=u'OTHER: 29: 1.74%', Most_Common_Vehicle_Type_5=u'LARGE COM VEH(6 OR MORE TIRES): 27: 1.62%', Top_Street_Complaint_1=u'STREET LIGHT CONDITION: 1: 100.0%', Top_Street_Complaint_2=u'', Top_Street_Complaint_3=u'', Top_Complaint_Description_1=u'Street Light Out: 1: 100.0%', Top_Complaint_Description_2=u'', Top_Complaint_Description_3=u'', Top_Complaint_Description_4=u'', Top_Complaint_Description_5=u'', Total Street Complaints=1),
#  Row(City=u'BRONX', Zip_Code=u'10462', Accidents_Per_1000_Vehicles=0.15000000596046448, Injuries_Per_1000_Accidents=266.3299865722656, Deaths_Per_1000_Accidents=0.7300000190734863, Vehicles_Involved_Per_Accident=1.9900000095367432, =1378, Total_Number_of_Vehicles_Involved_in_Accidents=2744, Top_Factor_1=u'Driver Inattention/Distraction: 113: 4.12%', Top_Factor_2=u'Failure to Yield Right-of-Way: 41: 1.49%', Top_Factor_3=u'Other Vehicular: 37: 1.35%', Top_Factor_4=u'Backing Unsafely: 34: 1.24%', Top_Factor_5=u'Prescription Medication: 25: 0.91%', Most_Common_Vehicle_Type_1=u'PASSENGER VEHICLE: 1614: 58.82%', Most_Common_Vehicle_Type_2=u'SPORT UTILITY / STATION WAGON: 452: 16.47%', Most_Common_Vehicle_Type_3=u'TAXI: 66: 2.41%', Most_Common_Vehicle_Type_4=u'VAN: 64: 2.33%', Most_Common_Vehicle_Type_5=u'OTHER: 52: 1.9%', Top_Street_Complaint_1=u'STREET LIGHT CONDITION: 1: 100.0%', Top_Street_Complaint_2=u'', Top_Street_Complaint_3=u'', Top_Complaint_Description_1=u'Street Light Out: 1: 100.0%', Top_Complaint_Description_2=u'', Top_Complaint_Description_3=u'', Top_Complaint_Description_4=u'', Top_Complaint_Description_5=u'', Total Street Complaints=1),
#  Row(City=u'BRONX', Zip_Code=u'10463', Accidents_Per_1000_Vehicles=0.05000000074505806, Injuries_Per_1000_Accidents=221.83999633789062, Deaths_Per_1000_Accidents=0.8600000143051147, Vehicles_Involved_Per_Accident=1.9700000286102295, =1163, Total_Number_of_Vehicles_Involved_in_Accidents=2291, Top_Factor_1=u'Driver Inattention/Distraction: 142: 6.2%', Top_Factor_2=u'Other Vehicular: 79: 3.45%', Top_Factor_3=u'Backing Unsafely: 52: 2.27%', Top_Factor_4=u'Failure to Yield Right-of-Way: 48: 2.1%', Top_Factor_5=u'Fatigued/Drowsy: 43: 1.88%', Most_Common_Vehicle_Type_1=u'PASSENGER VEHICLE: 1386: 60.5%', Most_Common_Vehicle_Type_2=u'SPORT UTILITY / STATION WAGON: 395: 17.24%', Most_Common_Vehicle_Type_3=u'OTHER: 53: 2.31%', Most_Common_Vehicle_Type_4=u'BUS: 40: 1.75%', Most_Common_Vehicle_Type_5=u'VAN: 37: 1.62%', Top_Street_Complaint_1=u'STREET CONDITION: 1: 100.0%', Top_Street_Complaint_2=u'', Top_Street_Complaint_3=u'', Top_Complaint_Description_1=u'Cave-in: 1: 100.0%', Top_Complaint_Description_2=u'', Top_Complaint_Description_3=u'', Top_Complaint_Description_4=u'', Top_Complaint_Description_5=u'', Total Street Complaints=1),
#  Row(City=u'Rosedale', Zip_Code=u'11422', Accidents_Per_1000_Vehicles=0.019999999552965164, Injuries_Per_1000_Accidents=329.7300109863281, Deaths_Per_1000_Accidents=3.859999895095825, Vehicles_Involved_Per_Accident=2.0399999618530273, =1295, Total_Number_of_Vehicles_Involved_in_Accidents=2639, Top_Factor_1=u'Driver Inattention/Distraction: 108: 4.09%', Top_Factor_2=u'Failure to Yield Right-of-Way: 88: 3.33%', Top_Factor_3=u'Fatigued/Drowsy: 79: 2.99%', Top_Factor_4=u'Turning Improperly: 25: 0.95%', Top_Factor_5=u'Other Vehicular: 24: 0.91%', Most_Common_Vehicle_Type_1=u'PASSENGER VEHICLE: 1644: 62.3%', Most_Common_Vehicle_Type_2=u'SPORT UTILITY / STATION WAGON: 632: 23.95%', Most_Common_Vehicle_Type_3=u'OTHER: 45: 1.71%', Most_Common_Vehicle_Type_4=u'VAN: 41: 1.55%', Most_Common_Vehicle_Type_5=u'PICK-UP TRUCK: 22: 0.83%', Top_Street_Complaint_1=u'STREET CONDITION: 1: 100.0%', Top_Street_Complaint_2=u'', Top_Street_Complaint_3=u'', Top_Complaint_Description_1=u'Pothole: 1: 100.0%', Top_Complaint_Description_2=u'', Top_Complaint_Description_3=u'', Top_Complaint_Description_4=u'', Top_Complaint_Description_5=u'', Total Street Complaints=1),
#  Row(City=u'Whitestone', Zip_Code=u'11357', Accidents_Per_1000_Vehicles=0.10999999940395355, Injuries_Per_1000_Accidents=250.77000427246094, Deaths_Per_1000_Accidents=0.0, Vehicles_Involved_Per_Accident=2.0799999237060547, =646, Total_Number_of_Vehicles_Involved_in_Accidents=1341, Top_Factor_1=u'Driver Inattention/Distraction: 49: 3.65%', Top_Factor_2=u'Failure to Yield Right-of-Way: 29: 2.16%', Top_Factor_3=u'Prescription Medication: 12: 0.89%', Top_Factor_4=u'Fatigued/Drowsy: 11: 0.82%', Top_Factor_5=u'Physical Disability: 9: 0.67%', Most_Common_Vehicle_Type_1=u'PASSENGER VEHICLE: 894: 66.67%', Most_Common_Vehicle_Type_2=u'SPORT UTILITY / STATION WAGON: 257: 19.16%', Most_Common_Vehicle_Type_3=u'OTHER: 38: 2.83%', Most_Common_Vehicle_Type_4=u'VAN: 16: 1.19%', Most_Common_Vehicle_Type_5=u'SMALL COM VEH(4 TIRES): 15: 1.12%', Top_Street_Complaint_1=u'STREET CONDITION: 1: 100.0%', Top_Street_Complaint_2=u'', Top_Street_Complaint_3=u'', Top_Complaint_Description_1=u'Pothole: 1: 100.0%', Top_Complaint_Description_2=u'', Top_Complaint_Description_3=u'', Top_Complaint_Description_4=u'', Top_Complaint_Description_5=u'', Total Street Complaints=1),
#  Row(City=u'BROOKLYN', Zip_Code=u'11210', Accidents_Per_1000_Vehicles=0.18000000715255737, Injuries_Per_1000_Accidents=406.7799987792969, Deaths_Per_1000_Accidents=1.2100000381469727, Vehicles_Involved_Per_Accident=2.0199999809265137, =1652, Total_Number_of_Vehicles_Involved_in_Accidents=3342, Top_Factor_1=u'Driver Inattention/Distraction: 87: 2.6%', Top_Factor_2=u'Failure to Yield Right-of-Way: 74: 2.21%', Top_Factor_3=u'Fatigued/Drowsy: 43: 1.29%', Top_Factor_4=u'Prescription Medication: 30: 0.9%', Top_Factor_5=u'Physical Disability: 27: 0.81%', Most_Common_Vehicle_Type_1=u'PASSENGER VEHICLE: 1841: 55.09%', Most_Common_Vehicle_Type_2=u'SPORT UTILITY / STATION WAGON: 852: 25.49%', Most_Common_Vehicle_Type_3=u'VAN: 118: 3.53%', Most_Common_Vehicle_Type_4=u'BUS: 87: 2.6%', Most_Common_Vehicle_Type_5=u'BICYCLE: 52: 1.56%', Top_Street_Complaint_1=u'STREET CONDITION: 1: 100.0%', Top_Street_Complaint_2=u'', Top_Street_Complaint_3=u'', Top_Complaint_Description_1=u'Pothole: 1: 100.0%', Top_Complaint_Description_2=u'', Top_Complaint_Description_3=u'', Top_Complaint_Description_4=u'', Top_Complaint_Description_5=u'', Total Street Complaints=1),
#  Row(City=u'BROOKLYN', Zip_Code=u'11216', Accidents_Per_1000_Vehicles=0.03999999910593033, Injuries_Per_1000_Accidents=329.5199890136719, Deaths_Per_1000_Accidents=0.5, Vehicles_Involved_Per_Accident=1.9700000286102295, =2012, Total_Number_of_Vehicles_Involved_in_Accidents=3964, Top_Factor_1=u'Driver Inattention/Distraction: 136: 3.43%', Top_Factor_2=u'Fatigued/Drowsy: 58: 1.46%', Top_Factor_3=u'Failure to Yield Right-of-Way: 45: 1.14%', Top_Factor_4=u'Lost Consciousness: 38: 0.96%', Top_Factor_5=u'Outside Car Distraction: 30: 0.76%', Most_Common_Vehicle_Type_1=u'PASSENGER VEHICLE: 2120: 53.48%', Most_Common_Vehicle_Type_2=u'SPORT UTILITY / STATION WAGON: 845: 21.32%', Most_Common_Vehicle_Type_3=u'VAN: 157: 3.96%', Most_Common_Vehicle_Type_4=u'BICYCLE: 124: 3.13%', Most_Common_Vehicle_Type_5=u'BUS: 68: 1.72%', Top_Street_Complaint_1=u'STREET CONDITION: 1: 100.0%', Top_Street_Complaint_2=u'', Top_Street_Complaint_3=u'', Top_Complaint_Description_1=u'Failed Street Repair: 1: 100.0%', Top_Complaint_Description_2=u'', Top_Complaint_Description_3=u'', Top_Complaint_Description_4=u'', Top_Complaint_Description_5=u'', Total Street Complaints=1),
#  Row(City=u'BROOKLYN', Zip_Code=u'11215', Accidents_Per_1000_Vehicles=0.07999999821186066, Injuries_Per_1000_Accidents=217.05999755859375, Deaths_Per_1000_Accidents=0.0, Vehicles_Involved_Per_Accident=1.9800000190734863, =1958, Total_Number_of_Vehicles_Involved_in_Accidents=3868, Top_Factor_1=u'Driver Inattention/Distraction: 204: 5.27%', Top_Factor_2=u'Failure to Yield Right-of-Way: 80: 2.07%', Top_Factor_3=u'Fatigued/Drowsy: 52: 1.34%', Top_Factor_4=u'Backing Unsafely: 47: 1.22%', Top_Factor_5=u'Lost Consciousness: 44: 1.14%', Most_Common_Vehicle_Type_1=u'PASSENGER VEHICLE: 2165: 55.97%', Most_Common_Vehicle_Type_2=u'SPORT UTILITY / STATION WAGON: 551: 14.25%', Most_Common_Vehicle_Type_3=u'VAN: 174: 4.5%', Most_Common_Vehicle_Type_4=u'OTHER: 152: 3.93%', Most_Common_Vehicle_Type_5=u'BICYCLE: 114: 2.95%', Top_Street_Complaint_1=u'STREET CONDITION: 1: 100.0%', Top_Street_Complaint_2=u'', Top_Street_Complaint_3=u'', Top_Complaint_Description_1=u'Pothole: 1: 100.0%', Top_Complaint_Description_2=u'', Top_Complaint_Description_3=u'', Top_Complaint_Description_4=u'', Top_Complaint_Description_5=u'', Total Street Complaints=1),
#  Row(City=u'BROOKLYN', Zip_Code=u'11219', Accidents_Per_1000_Vehicles=0.4399999976158142, Injuries_Per_1000_Accidents=263.2200012207031, Deaths_Per_1000_Accidents=1.7100000381469727, Vehicles_Involved_Per_Accident=1.9800000190734863, =1759, Total_Number_of_Vehicles_Involved_in_Accidents=3477, Top_Factor_1=u'Driver Inattention/Distraction: 226: 6.5%', Top_Factor_2=u'Failure to Yield Right-of-Way: 102: 2.93%', Top_Factor_3=u'Backing Unsafely: 48: 1.38%', Top_Factor_4=u'Fatigued/Drowsy: 47: 1.35%', Top_Factor_5=u'Other Vehicular: 33: 0.95%', Most_Common_Vehicle_Type_1=u'PASSENGER VEHICLE: 1573: 45.24%', Most_Common_Vehicle_Type_2=u'SPORT UTILITY / STATION WAGON: 1155: 33.22%', Most_Common_Vehicle_Type_3=u'VAN: 107: 3.08%', Most_Common_Vehicle_Type_4=u'BUS: 83: 2.39%', Most_Common_Vehicle_Type_5=u'LARGE COM VEH(6 OR MORE TIRES): 74: 2.13%', Top_Street_Complaint_1=u'STREET LIGHT CONDITION: 1: 100.0%', Top_Street_Complaint_2=u'', Top_Street_Complaint_3=u'', Top_Complaint_Description_1=u'Street Light Out: 1: 100.0%', Top_Complaint_Description_2=u'', Top_Complaint_Description_3=u'', Top_Complaint_Description_4=u'', Top_Complaint_Description_5=u'', Total Street Complaints=1)]

# %%
temp_df = full_df.describe(['Accidents_Per_1000_Vehicles', 'Injuries_Per_1000_Accidents', 'Deaths_Per_1000_Accidents', 'Vehicles_Involved_Per_Accident'])
new_df = temp_df.select(temp_df.summary,
                        temp_df.Accidents_Per_1000_Vehicles.cast(FloatType()).alias('Accidents'),
                        temp_df.Injuries_Per_1000_Accidents.cast(FloatType()).alias('Injuries'),
                        temp_df.Deaths_Per_1000_Accidents.cast(FloatType()).alias('Deaths'),
                        temp_df.Vehicles_Involved_Per_Accident.cast(FloatType()).alias('Vehicles'))
 
temp_lst = new_df.collect()



avg_row = temp_lst[1]
avg_accidents_per_1000             = round(avg_row.Accidents, 4)
avg_injuries_per_1000              = round(avg_row.Injuries, 4)
avg_deaths_per_1000                = round(avg_row.Deaths, 4)
avg_vehicles_involved_per_accident = round(avg_row.Vehicles, 4)
std_dev_row = temp_lst[2]
std_dev_accidents_per_1000             = round(std_dev_row.Accidents, 4)
std_dev_injuries_per_1000              = round(std_dev_row.Injuries, 4)
std_dev_deaths_per_1000                = round(std_dev_row.Deaths, 4)
std_dev_vehicles_involved_per_accident = round(std_dev_row.Vehicles, 4)

one_std_dev_accidents   = std_dev_accidents_per_1000
two_std_dev_accidents   = 2 * one_std_dev_accidents
three_std_dev_accidents = 3 * one_std_dev_accidents

one_std_dev_injuries    = std_dev_injuries_per_1000
two_std_dev_injuries    = 2 * one_std_dev_injuries
three_std_dev_injuries  = 3 * one_std_dev_injuries
        
one_std_dev_deaths      = std_dev_deaths_per_1000
two_std_dev_deaths      = 2 * one_std_dev_deaths
three_std_dev_deaths    = 3 * one_std_dev_deaths
        
one_std_dev_vehicles    = std_dev_vehicles_involved_per_accident
two_std_dev_vehicles    = 2 * one_std_dev_vehicles
three_std_dev_vehicles  = 3 * one_std_dev_vehicles

# %%
top_10_accidents_per_1000_vehicles       = map(lambda x: x.asDict(), full_df.sort('Accidents_Per_1000_Vehicles', ascending=False).take(10))
top_10_injuries_per_1000_accidents       = map(lambda x: x.asDict(), full_df.sort('Injuries_Per_1000_Accidents', ascending=False).take(10))
top_10_deaths_per_1000_accidents         = map(lambda x: x.asDict(), full_df.sort('Deaths_Per_1000_Accidents', ascending=False).take(10))
top_10_vehicles_involved_per_accident    = map(lambda x: x.asDict(), full_df.sort('Vehicles_Involved_Per_Accident', ascending=False).take(10))

bottom_10_accidents_per_1000_vehicles    = map(lambda x: x.asDict(), full_df.sort('Accidents_Per_1000_Vehicles', ascending=True).take(10))
bottom_10_injuries_per_1000_accidents    = map(lambda x: x.asDict(), full_df.sort('Injuries_Per_1000_Accidents', ascending=True).take(10))
bottom_10_deaths_per_1000_accidents      = map(lambda x: x.asDict(), full_df.sort('Deaths_Per_1000_Accidents', ascending=True).take(10))
bottom_10_vehicles_involved_per_accident = map(lambda x: x.asDict(), full_df.sort('Vehicles_Involved_Per_Accident', ascending=True).take(10))

# %%
def classify_mapper(records):
    for record in records:
        city = record[0]
        zip_code = record[1]
        accidents_per_1000 = record[2]
        injuries_per_1000 = record[3]
        deaths_per_1000 = record[4]
        vehicles_involved_per_accident = record[5]
        
        upper_a_bound = round(avg_accidents_per_1000 + one_std_dev_accidents, 4)
        lower_a_bound = round(avg_accidents_per_1000 - one_std_dev_accidents, 4)
        
        upper_i_bound = round(avg_injuries_per_1000 + one_std_dev_injuries, 4)
        lower_i_bound = round(avg_injuries_per_1000 - one_std_dev_injuries, 4)
        
        upper_d_bound = round(avg_deaths_per_1000 + one_std_dev_deaths, 4)
        lower_d_bound = round(avg_deaths_per_1000 - one_std_dev_deaths, 4)
        
        zip_safety_level = ""
        
        if accidents_per_1000 > upper_a_bound:
            if injuries_per_1000 < lower_i_bound and deaths_per_1000 < lower_d_bound:
                print ("{} is classified as Ok with {} A {} I {} D ".format(zip_code, accidents_per_1000, injuries_per_1000, deaths_per_1000))
                zip_safety_level = "Ok"
            else:
                print ("{} is classified as Hazardous with {} accidents per 1000 vehicles".format(zip_code, accidents_per_1000))
                zip_safety_level = "Hazardous"
        elif accidents_per_1000 < lower_a_bound:
            if injuries_per_1000 > upper_i_bound and deaths_per_1000 > upper_d_bound:
                print ("{} is classified as Ok with {} A {} I {} D ".format(zip_code, accidents_per_1000, injuries_per_1000, deaths_per_1000))
                zip_safety_level = "Ok"
            else:
                print("{} is classified as Safe with {} accidents per 1000 vehicles".format(zip_code, accidents_per_1000))
                zip_safety_level = "Safe"
        else:
            # accidents_per_1000 falls within one std deviation of mean
            if injuries_per_1000 > upper_i_bound and deaths_per_1000 > upper_d_bound:
                print("{} is classified as Hazardous with {} A {} I {} D ".format(zip_code, accidents_per_1000, injuries_per_1000, deaths_per_1000))
                zip_safety_level = "Hazardous"
            elif injuries_per_1000 < lower_i_bound and deaths_per_1000 < lower_d_bound:
                print("{} is classified as Safe with {} A {} I {} D ".format(zip_code, accidents_per_1000, injuries_per_1000, deaths_per_1000))
                zip_safety_level = "Safe"
            else:
                print ("{} is classified as Ok with {} accidents per 1000 vehicles".format(zip_code, accidents_per_1000))
                zip_safety_level = "Ok"
                
        
        yield (city, zip_code, zip_safety_level,
              accidents_per_1000, injuries_per_1000, deaths_per_1000, vehicles_involved_per_accident,
              record[6], record[7], record[8], record[9], record[10], record[11], record[12], record[13],
              record[14], record[15], record[16], record[17], record[18], record[19], record[20], record[21],
              record[22], record[23], record[24], record[25], record[26])

        
final_rdd = full_rdd.mapPartitions(classify_mapper)
final_rdd.collect()
# Out:
# [('STATEN ISLAND',
#   u'10314',
#   'Ok',
#   0.11,
#   239.88,
#   1.74,
#   1.99,
#   2297,
#   4582,
#   'Driver Inattention/Distraction: 281: 6.13%',
#   'Fatigued/Drowsy: 154: 3.36%',
#   'Failure to Yield Right-of-Way: 92: 2.01%',
#   'Pavement Slippery: 70: 1.53%',
#   'Other Vehicular: 52: 1.13%',
#   'PASSENGER VEHICLE: 3124: 68.18%',
#   'SPORT UTILITY / STATION WAGON: 950: 20.73%',
#   'OTHER: 75: 1.64%',
#   'PICK-UP TRUCK: 56: 1.22%',
#   'VAN: 53: 1.16%',
#   'STREET LIGHT CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Street Light Out: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BROOKLYN',
#   u'11232',
#   'Ok',
#   0.21,
#   228.72,
#   0.0,
#   1.99,
#   1351,
#   2684,
#   'Driver Inattention/Distraction: 195: 7.27%',
#   'Failure to Yield Right-of-Way: 82: 3.06%',
#   'Backing Unsafely: 80: 2.98%',
#   'Fatigued/Drowsy: 62: 2.31%',
#   'Driver Inexperience: 50: 1.86%',
#   'PASSENGER VEHICLE: 1652: 61.55%',
#   'SPORT UTILITY / STATION WAGON: 309: 11.51%',
#   'SMALL COM VEH(4 TIRES): 115: 4.28%',
#   'VAN: 109: 4.06%',
#   'LARGE COM VEH(6 OR MORE TIRES): 107: 3.99%',
#   'STREET LIGHT CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Street Light Dayburning: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BROOKLYN',
#   u'11233',
#   'Hazardous',
#   0.25,
#   421.43,
#   0.96,
#   1.98,
#   2081,
#   4116,
#   'Driver Inattention/Distraction: 182: 4.42%',
#   'Fatigued/Drowsy: 64: 1.55%',
#   'Failure to Yield Right-of-Way: 59: 1.43%',
#   'Turning Improperly: 31: 0.75%',
#   'Prescription Medication: 30: 0.73%',
#   'PASSENGER VEHICLE: 2470: 60.01%',
#   'SPORT UTILITY / STATION WAGON: 823: 20.0%',
#   'VAN: 88: 2.14%',
#   'OTHER: 78: 1.9%',
#   'BICYCLE: 73: 1.77%',
#   'STREET LIGHT CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Street Light Out: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('NEW YORK',
#   u'10003',
#   'Ok',
#   0.18,
#   210.72,
#   0.92,
#   1.92,
#   2164,
#   4155,
#   'Driver Inattention/Distraction: 225: 5.42%',
#   'Fatigued/Drowsy: 79: 1.9%',
#   'Lost Consciousness: 67: 1.61%',
#   'Backing Unsafely: 61: 1.47%',
#   'Failure to Yield Right-of-Way: 58: 1.4%',
#   'PASSENGER VEHICLE: 1621: 39.01%',
#   'TAXI: 855: 20.58%',
#   'SPORT UTILITY / STATION WAGON: 475: 11.43%',
#   'VAN: 200: 4.81%',
#   'BICYCLE: 154: 3.71%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Pothole: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('Oakland Gardens',
#   u'11364',
#   'Ok',
#   0.06,
#   236.84,
#   6.19,
#   1.99,
#   646,
#   1283,
#   'Driver Inattention/Distraction: 122: 9.51%',
#   'Failure to Yield Right-of-Way: 111: 8.65%',
#   'Fatigued/Drowsy: 65: 5.07%',
#   'Backing Unsafely: 54: 4.21%',
#   'Prescription Medication: 30: 2.34%',
#   'PASSENGER VEHICLE: 744: 57.99%',
#   'SPORT UTILITY / STATION WAGON: 369: 28.76%',
#   'VAN: 31: 2.42%',
#   'BUS: 16: 1.25%',
#   'OTHER: 15: 1.17%',
#   'STREET LIGHT CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Street Light Out: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BROOKLYN',
#   u'11207',
#   'Hazardous',
#   0.26,
#   427.16,
#   0.99,
#   2.0,
#   4050,
#   8088,
#   'Driver Inattention/Distraction: 127: 1.57%',
#   'Failure to Yield Right-of-Way: 59: 0.73%',
#   'Other Vehicular: 50: 0.62%',
#   'Fatigued/Drowsy: 42: 0.52%',
#   'Backing Unsafely: 26: 0.32%',
#   'PASSENGER VEHICLE: 5041: 62.33%',
#   'SPORT UTILITY / STATION WAGON: 1297: 16.04%',
#   'OTHER: 374: 4.62%',
#   'VAN: 192: 2.37%',
#   'BICYCLE: 119: 1.47%',
#   'STREET LIGHT CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Street Light Dayburning: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BROOKLYN',
#   u'11208',
#   'Ok',
#   0.05,
#   398.75,
#   2.24,
#   1.99,
#   2232,
#   4438,
#   'Driver Inattention/Distraction: 88: 1.98%',
#   'Failure to Yield Right-of-Way: 39: 0.88%',
#   'Other Vehicular: 34: 0.77%',
#   'Physical Disability: 18: 0.41%',
#   'Traffic Control Disregarded: 17: 0.38%',
#   'PASSENGER VEHICLE: 2781: 62.66%',
#   'SPORT UTILITY / STATION WAGON: 698: 15.73%',
#   'VAN: 91: 2.05%',
#   'OTHER: 82: 1.85%',
#   'PICK-UP TRUCK: 64: 1.44%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Pothole: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BROOKLYN',
#   u'11226',
#   'Ok',
#   0.19,
#   409.5,
#   0.81,
#   1.98,
#   2464,
#   4874,
#   'Driver Inattention/Distraction: 154: 3.16%',
#   'Fatigued/Drowsy: 69: 1.42%',
#   'Failure to Yield Right-of-Way: 61: 1.25%',
#   'Other Vehicular: 51: 1.05%',
#   'Backing Unsafely: 40: 0.82%',
#   'PASSENGER VEHICLE: 2543: 52.17%',
#   'SPORT UTILITY / STATION WAGON: 1229: 25.22%',
#   'VAN: 200: 4.1%',
#   'BICYCLE: 113: 2.32%',
#   'BUS: 94: 1.93%',
#   'STREET SIGN - DAMAGED: 1: 100.0%',
#   '',
#   '',
#   'Street Cleaning - ASP: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('NEW YORK',
#   u'10032',
#   'Ok',
#   0.13,
#   302.47,
#   0.88,
#   1.93,
#   1134,
#   2193,
#   'Driver Inattention/Distraction: 67: 3.06%',
#   'Other Vehicular: 41: 1.87%',
#   'Failure to Yield Right-of-Way: 32: 1.46%',
#   'Fatigued/Drowsy: 23: 1.05%',
#   'Backing Unsafely: 22: 1.0%',
#   'PASSENGER VEHICLE: 1051: 47.93%',
#   'SPORT UTILITY / STATION WAGON: 439: 20.02%',
#   'OTHER: 140: 6.38%',
#   'VAN: 101: 4.61%',
#   'TAXI: 87: 3.97%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Pothole: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('NEW YORK',
#   u'10019',
#   'Ok',
#   0.17,
#   143.33,
#   0.91,
#   1.94,
#   3307,
#   6415,
#   'Driver Inattention/Distraction: 1051: 16.38%',
#   'Fatigued/Drowsy: 427: 6.66%',
#   'Turning Improperly: 369: 5.75%',
#   'Lost Consciousness: 314: 4.89%',
#   'Failure to Yield Right-of-Way: 206: 3.21%',
#   'PASSENGER VEHICLE: 2310: 36.01%',
#   'TAXI: 1202: 18.74%',
#   'SPORT UTILITY / STATION WAGON: 1059: 16.51%',
#   'VAN: 385: 6.0%',
#   'LARGE COM VEH(6 OR MORE TIRES): 227: 3.54%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Cave-in: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BRONX',
#   u'10465',
#   'Ok',
#   0.05,
#   301.32,
#   0.0,
#   2.0,
#   833,
#   1667,
#   'Driver Inattention/Distraction: 56: 3.36%',
#   'Failure to Yield Right-of-Way: 38: 2.28%',
#   'Backing Unsafely: 33: 1.98%',
#   'Prescription Medication: 22: 1.32%',
#   'Fatigued/Drowsy: 18: 1.08%',
#   'PASSENGER VEHICLE: 1095: 65.69%',
#   'SPORT UTILITY / STATION WAGON: 240: 14.4%',
#   'VAN: 29: 1.74%',
#   'OTHER: 29: 1.74%',
#   'LARGE COM VEH(6 OR MORE TIRES): 27: 1.62%',
#   'STREET LIGHT CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Street Light Out: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BRONX',
#   u'10462',
#   'Ok',
#   0.15,
#   266.33,
#   0.73,
#   1.99,
#   1378,
#   2744,
#   'Driver Inattention/Distraction: 113: 4.12%',
#   'Failure to Yield Right-of-Way: 41: 1.49%',
#   'Other Vehicular: 37: 1.35%',
#   'Backing Unsafely: 34: 1.24%',
#   'Prescription Medication: 25: 0.91%',
#   'PASSENGER VEHICLE: 1614: 58.82%',
#   'SPORT UTILITY / STATION WAGON: 452: 16.47%',
#   'TAXI: 66: 2.41%',
#   'VAN: 64: 2.33%',
#   'OTHER: 52: 1.9%',
#   'STREET LIGHT CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Street Light Out: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BRONX',
#   u'10463',
#   'Ok',
#   0.05,
#   221.84,
#   0.86,
#   1.97,
#   1163,
#   2291,
#   'Driver Inattention/Distraction: 142: 6.2%',
#   'Other Vehicular: 79: 3.45%',
#   'Backing Unsafely: 52: 2.27%',
#   'Failure to Yield Right-of-Way: 48: 2.1%',
#   'Fatigued/Drowsy: 43: 1.88%',
#   'PASSENGER VEHICLE: 1386: 60.5%',
#   'SPORT UTILITY / STATION WAGON: 395: 17.24%',
#   'OTHER: 53: 2.31%',
#   'BUS: 40: 1.75%',
#   'VAN: 37: 1.62%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Cave-in: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('Rosedale',
#   u'11422',
#   'Safe',
#   0.02,
#   329.73,
#   3.86,
#   2.04,
#   1295,
#   2639,
#   'Driver Inattention/Distraction: 108: 4.09%',
#   'Failure to Yield Right-of-Way: 88: 3.33%',
#   'Fatigued/Drowsy: 79: 2.99%',
#   'Turning Improperly: 25: 0.95%',
#   'Other Vehicular: 24: 0.91%',
#   'PASSENGER VEHICLE: 1644: 62.3%',
#   'SPORT UTILITY / STATION WAGON: 632: 23.95%',
#   'OTHER: 45: 1.71%',
#   'VAN: 41: 1.55%',
#   'PICK-UP TRUCK: 22: 0.83%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Pothole: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('Whitestone',
#   u'11357',
#   'Ok',
#   0.11,
#   250.77,
#   0.0,
#   2.08,
#   646,
#   1341,
#   'Driver Inattention/Distraction: 49: 3.65%',
#   'Failure to Yield Right-of-Way: 29: 2.16%',
#   'Prescription Medication: 12: 0.89%',
#   'Fatigued/Drowsy: 11: 0.82%',
#   'Physical Disability: 9: 0.67%',
#   'PASSENGER VEHICLE: 894: 66.67%',
#   'SPORT UTILITY / STATION WAGON: 257: 19.16%',
#   'OTHER: 38: 2.83%',
#   'VAN: 16: 1.19%',
#   'SMALL COM VEH(4 TIRES): 15: 1.12%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Pothole: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BROOKLYN',
#   u'11210',
#   'Ok',
#   0.18,
#   406.78,
#   1.21,
#   2.02,
#   1652,
#   3342,
#   'Driver Inattention/Distraction: 87: 2.6%',
#   'Failure to Yield Right-of-Way: 74: 2.21%',
#   'Fatigued/Drowsy: 43: 1.29%',
#   'Prescription Medication: 30: 0.9%',
#   'Physical Disability: 27: 0.81%',
#   'PASSENGER VEHICLE: 1841: 55.09%',
#   'SPORT UTILITY / STATION WAGON: 852: 25.49%',
#   'VAN: 118: 3.53%',
#   'BUS: 87: 2.6%',
#   'BICYCLE: 52: 1.56%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Pothole: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BROOKLYN',
#   u'11216',
#   'Safe',
#   0.04,
#   329.52,
#   0.5,
#   1.97,
#   2012,
#   3964,
#   'Driver Inattention/Distraction: 136: 3.43%',
#   'Fatigued/Drowsy: 58: 1.46%',
#   'Failure to Yield Right-of-Way: 45: 1.14%',
#   'Lost Consciousness: 38: 0.96%',
#   'Outside Car Distraction: 30: 0.76%',
#   'PASSENGER VEHICLE: 2120: 53.48%',
#   'SPORT UTILITY / STATION WAGON: 845: 21.32%',
#   'VAN: 157: 3.96%',
#   'BICYCLE: 124: 3.13%',
#   'BUS: 68: 1.72%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Failed Street Repair: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BROOKLYN',
#   u'11215',
#   'Ok',
#   0.08,
#   217.06,
#   0.0,
#   1.98,
#   1958,
#   3868,
#   'Driver Inattention/Distraction: 204: 5.27%',
#   'Failure to Yield Right-of-Way: 80: 2.07%',
#   'Fatigued/Drowsy: 52: 1.34%',
#   'Backing Unsafely: 47: 1.22%',
#   'Lost Consciousness: 44: 1.14%',
#   'PASSENGER VEHICLE: 2165: 55.97%',
#   'SPORT UTILITY / STATION WAGON: 551: 14.25%',
#   'VAN: 174: 4.5%',
#   'OTHER: 152: 3.93%',
#   'BICYCLE: 114: 2.95%',
#   'STREET CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Pothole: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1),
#  ('BROOKLYN',
#   u'11219',
#   'Hazardous',
#   0.44,
#   263.22,
#   1.71,
#   1.98,
#   1759,
#   3477,
#   'Driver Inattention/Distraction: 226: 6.5%',
#   'Failure to Yield Right-of-Way: 102: 2.93%',
#   'Backing Unsafely: 48: 1.38%',
#   'Fatigued/Drowsy: 47: 1.35%',
#   'Other Vehicular: 33: 0.95%',
#   'PASSENGER VEHICLE: 1573: 45.24%',
#   'SPORT UTILITY / STATION WAGON: 1155: 33.22%',
#   'VAN: 107: 3.08%',
#   'BUS: 83: 2.39%',
#   'LARGE COM VEH(6 OR MORE TIRES): 74: 2.13%',
#   'STREET LIGHT CONDITION: 1: 100.0%',
#   '',
#   '',
#   'Street Light Out: 1: 100.0%',
#   '',
#   '',
#   '',
#   '',
#   1)]

# %%
def toCSVLine(data):
    return ','.join(str(d) for d in data)

final_rdd.map(toCSVLine).coalesce(1).saveAsTextFile("FinalProjectOutputs/results/final_result")

sc.parallelize(top_10_accidents_per_1000_vehicles).coalesce(1).saveAsTextFile("FinalProjectOutputs/totals/top_ten/top_ten_accidents_per_1000_vehicles")
sc.parallelize(top_10_injuries_per_1000_accidents).coalesce(1).saveAsTextFile("FinalProjectOutputs/totals/top_ten/top_ten_injuries_per_1000_accidents")
sc.parallelize(top_10_deaths_per_1000_accidents).coalesce(1).saveAsTextFile("FinalProjectOutputs/totals/top_ten/top_ten_deaths_per_1000_accidents")
sc.parallelize(top_10_vehicles_involved_per_accident).coalesce(1).saveAsTextFile("FinalProjectOutputs/totals/top_ten/top_ten_vehicles_involved_per_accident")

sc.parallelize(bottom_10_accidents_per_1000_vehicles).coalesce(1).saveAsTextFile("FinalProjectOutputs/totals/bottom_ten/bottom_ten_accidents_per_1000_vehicles")
sc.parallelize(bottom_10_injuries_per_1000_accidents).coalesce(1).saveAsTextFile("FinalProjectOutputs/totals/bottom_ten/bottom_ten_injuries_per_1000_accidents")
sc.parallelize(bottom_10_deaths_per_1000_accidents).coalesce(1).saveAsTextFile("FinalProjectOutputs/totals/bottom_ten/bottom_ten_deaths_per_1000_accidents")
sc.parallelize(bottom_10_vehicles_involved_per_accident).coalesce(1).saveAsTextFile("FinalProjectOutputs/totals/bottom_ten/bottom_ten_vehicles_involved_per_accident")
