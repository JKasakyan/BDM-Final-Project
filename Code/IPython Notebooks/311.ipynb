# %%
rdd = sc.textFile("../../Datasets/311_Service_Requests_from_2010_to_Present.csv").cache()
header = rdd.first()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-2-3253fb335c08> in <module>()
#       1 rdd = sc.textFile("../../Datasets/311_Service_Requests_from_2010_to_Present.csv").cache()
# ----> 2 header = rdd.first()
#
# /Applications/spark-1.6.1-bin-hadoop2.6/python/pyspark/rdd.pyc in first(self)
#    1313         ValueError: RDD is empty
#    1314         """
# -> 1315         rs = self.take(1)
#    1316         if rs:
#    1317             return rs[0]
#
# /Applications/spark-1.6.1-bin-hadoop2.6/python/pyspark/rdd.pyc in take(self, num)
#    1265         """
#    1266         items = []
# -> 1267         totalParts = self.getNumPartitions()
#    1268         partsScanned = 0
#    1269
#
# /Applications/spark-1.6.1-bin-hadoop2.6/python/pyspark/rdd.pyc in getNumPartitions(self)
#     354         2
#     355         """
# --> 356         return self._jrdd.partitions().size()
#     357
#     358     def filter(self, f):
#
# /Applications/spark-1.6.1-bin-hadoop2.6/python/lib/py4j-0.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#     811         answer = self.gateway_client.send_command(command)
#     812         return_value = get_return_value(
# --> 813             answer, self.gateway_client, self.target_id, self.name)
#     814
#     815         for temp_arg in temp_args:
#
# /Applications/spark-1.6.1-bin-hadoop2.6/python/pyspark/sql/utils.pyc in deco(*a, **kw)
#      43     def deco(*a, **kw):
#      44         try:
# ---> 45             return f(*a, **kw)
#      46         except py4j.protocol.Py4JJavaError as e:
#      47             s = e.java_exception.toString()
#
# /Applications/spark-1.6.1-bin-hadoop2.6/python/lib/py4j-0.9-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     306                 raise Py4JJavaError(
#     307                     "An error occurred while calling {0}{1}{2}.\n".
# --> 308                     format(target_id, ".", name), value)
#     309             else:
#     310                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling o53.partitions.
# : org.apache.hadoop.mapred.InvalidInputException: Input path does not exist: file:/Users/James/Documents/School/Spring 2016/Big Data Management CSC 59927/BDM-Final-Project/Datasets/311_Service_Requests_from_2010_to_Present.csv
# 	at org.apache.hadoop.mapred.FileInputFormat.singleThreadedListStatus(FileInputFormat.java:285)
# 	at org.apache.hadoop.mapred.FileInputFormat.listStatus(FileInputFormat.java:228)
# 	at org.apache.hadoop.mapred.FileInputFormat.getSplits(FileInputFormat.java:313)
# 	at org.apache.spark.rdd.HadoopRDD.getPartitions(HadoopRDD.scala:199)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:239)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:237)
# 	at scala.Option.getOrElse(Option.scala:120)
# 	at org.apache.spark.rdd.RDD.partitions(RDD.scala:237)
# 	at org.apache.spark.rdd.MapPartitionsRDD.getPartitions(MapPartitionsRDD.scala:35)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:239)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:237)
# 	at scala.Option.getOrElse(Option.scala:120)
# 	at org.apache.spark.rdd.RDD.partitions(RDD.scala:237)
# 	at org.apache.spark.api.java.JavaRDDLike$class.partitions(JavaRDDLike.scala:64)
# 	at org.apache.spark.api.java.AbstractJavaRDDLike.partitions(JavaRDDLike.scala:46)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:483)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:231)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:381)
# 	at py4j.Gateway.invoke(Gateway.java:259)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:133)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:209)
# 	at java.lang.Thread.run(Thread.java:745)

# %%
lof = header.split(',')
list(enumerate(lof))

# %%
from datetime import datetime
from dateutil.parser import parse


def select_fields(records):
        first_day_2012 = datetime(year=2012, month=1, day=1, hour=0, minute=0)
        last_day_2013 = datetime(year=2013, month=12, day=31, hour=23, minute=59)
        for record in records:
            if record == header:
                continue
            fields = record.split(',')
            complaint_type = fields[5]
            zip_code = fields[8]
            city = fields[16]
            try:
                date_parsed = parse(fields[1])
            except ValueError:
                continue
            try:
                zip_code = int(fields[8])
                descriptor = fields[6]
            except ValueError:
                if zip_code == "":
                    continue
                elif "Street Sign" in complaint_type:
                    zip_code = fields[10]
                    descriptor = "{} {} {}".format(fields[6], fields[7], fields[8])
                    city = fields[18]
                else:
                    zip_code = fields[9]
                    descriptor = "{} {}".format(fields[6], fields[7])
                    city = fields[17]

            if (first_day_2012 <= date_parsed <= last_day_2013 and zip_code != "" and city != "" and "Street" in complaint_type and "Noise" not in complaint_type):
                yield (str(zip_code), (str(complaint_type).upper(), str(descriptor), str(city).lower().capitalize()))

filtered_rdd = rdd.sample(False, .0001).mapPartitions(select_fields)
filtered_rdd.collect()
# Out:
# [('10032', ('STREET CONDITION', 'Pothole', 'New york')),
#  ('11215', ('STREET LIGHT CONDITION', 'Street Light Out', 'Brooklyn')),
#  ('10473', ('STREET LIGHT CONDITION', 'Street Light Out', 'Bronx')),
#  ('11225', ('STREET LIGHT CONDITION', 'Street Light Out', 'Brooklyn')),
#  ('11205', ('STREET CONDITION', 'Wear & Tear', 'Brooklyn')),
#  ('11429', ('STREET LIGHT CONDITION', 'Glassware Hanging', 'Queens village')),
#  ('10461', ('STREET LIGHT CONDITION', 'Street Light Out', 'Bronx')),
#  ('11214', ('STREET LIGHT CONDITION', 'Street Light Out', 'Brooklyn')),
#  ('11368', ('STREET LIGHT CONDITION', 'Street Light Out', 'Corona')),
#  ('10461', ('STREET CONDITION', 'Pothole', 'Bronx')),
#  ('11369', ('STREET LIGHT CONDITION', 'Street Light Out', 'East elmhurst')),
#  ('10309', ('STREET LIGHT CONDITION', 'Street Light Out', 'Staten island')),
#  ('11364', ('STREET CONDITION', 'Pothole', 'Oakland gardens')),
#  ('11210', ('STREET CONDITION', 'Pothole', 'Brooklyn')),
#  ('11205', ('STREET CONDITION', 'Blocked - Construction', 'Brooklyn')),
#  ('10069', ('STREET SIGN - DANGLING', 'Bus Stop', 'New york')),
#  ('11422',
#   ('STREET CONDITION', '"Rough  Pitted or Cracked Roads"', 'Rosedale')),
#  ('10465', ('STREET CONDITION', '"Rough  Pitted or Cracked Roads"', 'Bronx')),
#  ('11231', ('STREET CONDITION', 'Defective Hardware', 'Brooklyn')),
#  ('10464', ('STREET SIGN - MISSING', 'St Name - Attached to Pole', 'Bronx')),
#  ('10022', ('STREET CONDITION', 'Failed Street Repair', 'New york')),
#  ('11234', ('STREET SIGN - DANGLING', 'School Crossing', 'Brooklyn'))]

# %%
def seqOp(agg_dict, record):
        complaint_type = record[0]
        descriptor = record[1]
        agg_dict["total_complaints"] = agg_dict.get("total_complaints", 0) + 1
        agg_dict[complaint_type] = agg_dict.get(complaint_type, 0) + 1
        agg_dict[descriptor] = agg_dict.get(descriptor, 0) + 1
        agg_dict['city'] = record[2]
        return agg_dict

def combOp (dict1, dict2):
    for key, value in dict1.items():
        if key != "city":
            dict2[key] = dict2.get(key, 0) + value
    return dict2
    
zip_complaints_rdd = filtered_rdd.aggregateByKey({}, seqOp, combOp)
zip_complaints_rdd.collect()
# Out:
# [('10461',
#   {'"Rough  Pitted or Cracked Roads"': 1,
#    'STREET CONDITION': 1,
#    'STREET LIGHT CONDITION': 1,
#    'Street Light Out': 1,
#    'city': 'Bronx',
#    'total_complaints': 2}),
#  ('10128',
#   {'Plate Condition - Noisy': 1,
#    'STREET CONDITION': 1,
#    'city': 'New york',
#    'total_complaints': 1}),
#  ('11375',
#   {'STREET LIGHT CONDITION': 1,
#    'Street Light Out': 1,
#    'city': 'Forest hills',
#    'total_complaints': 1}),
#  ('11385',
#   {'Cave-in': 1,
#    'STREET CONDITION': 1,
#    'city': 'Ridgewood',
#    'total_complaints': 1}),
#  ('10001',
#   {'Pothole': 1,
#    'STREET CONDITION': 1,
#    'city': 'New york',
#    'total_complaints': 1}),
#  ('10312',
#   {'Pothole': 1,
#    'STREET CONDITION': 1,
#    'city': 'Staten island',
#    'total_complaints': 1}),
#  ('10314',
#   {'STREET LIGHT CONDITION': 1,
#    'Street Light Out': 1,
#    'city': 'Staten island',
#    'total_complaints': 1}),
#  ('10306',
#   {'Pothole': 1,
#    'STREET CONDITION': 1,
#    'city': 'Staten island',
#    'total_complaints': 1}),
#  ('10016',
#   {'Pothole': 1,
#    'STREET CONDITION': 1,
#    'city': 'New york',
#    'total_complaints': 1}),
#  ('10014',
#   {'Pothole': 1,
#    'STREET CONDITION': 1,
#    'city': 'New york',
#    'total_complaints': 1}),
#  ('10022',
#   {'Plate Condition - Noisy': 1,
#    'STREET CONDITION': 1,
#    'city': 'New york',
#    'total_complaints': 1}),
#  ('11412',
#   {'Pothole': 1,
#    'STREET CONDITION': 1,
#    'city': 'Saint albans',
#    'total_complaints': 1}),
#  ('11415',
#   {'STREET LIGHT CONDITION': 1,
#    'Street Light Out': 1,
#    'city': 'Kew gardens',
#    'total_complaints': 1}),
#  ('11231',
#   {'Pothole': 1,
#    'STREET CONDITION': 1,
#    'STREET SIGN - MISSING': 1,
#    'Stop': 1,
#    'city': 'Brooklyn',
#    'total_complaints': 2}),
#  ('11232',
#   {'STREET LIGHT CONDITION': 1,
#    'Street Light Out': 1,
#    'city': 'Brooklyn',
#    'total_complaints': 1}),
#  ('11237',
#   {'"Rough  Pitted or Cracked Roads"': 1,
#    'STREET CONDITION': 1,
#    'city': 'Queens',
#    'total_complaints': 1}),
#  ('11210',
#   {'Pothole': 1,
#    'STREET CONDITION': 1,
#    'city': 'Brooklyn',
#    'total_complaints': 1}),
#  ('11211',
#   {'"Rough  Pitted or Cracked Roads"': 1,
#    'STREET CONDITION': 1,
#    'city': 'Brooklyn',
#    'total_complaints': 1}),
#  ('11217',
#   {'"No Parking  Standing  Stopping"': 1,
#    'STREET SIGN - DAMAGED': 1,
#    'city': 'Brooklyn',
#    'total_complaints': 1}),
#  ('11220',
#   {'Plate Condition - Open': 1,
#    'STREET CONDITION': 1,
#    'city': 'Brooklyn',
#    'total_complaints': 1}),
#  ('11203',
#   {'Pothole': 1,
#    'STREET CONDITION': 1,
#    'city': 'Brooklyn',
#    'total_complaints': 1}),
#  ('11219',
#   {'Plate Condition - Noisy': 1,
#    'STREET CONDITION': 1,
#    'city': 'Brooklyn',
#    'total_complaints': 1}),
#  ('11207',
#   {'STREET LIGHT CONDITION': 1,
#    'Street Light Out': 1,
#    'city': 'Brooklyn',
#    'total_complaints': 1}),
#  ('11434',
#   {'Pothole': 1,
#    'STREET CONDITION': 1,
#    'city': 'Jamaica',
#    'total_complaints': 1}),
#  ('11427',
#   {'Pothole': 1,
#    'STREET CONDITION': 1,
#    'city': 'Queens village',
#    'total_complaints': 1}),
#  ('11358',
#   {'STREET LIGHT CONDITION': 1,
#    'Street Light Out': 1,
#    'city': 'Flushing',
#    'total_complaints': 1})]

# %%
from heapq import nlargest
        
def topn(zip_tuples):
        for zip_tuple in zip_tuples:
            zip_code = zip_tuple[0]
            zip_dict = zip_tuple[1]
            city = zip_dict["city"]
            total_complaints = float(zip_dict['total_complaints'])
            complaints_dict = {k:v for (k,v) in zip_dict.items() if k.isupper() }
            descriptors_dict = {k:v for (k,v) in zip_dict.items() if not k.isupper() and k != 'total_complaints' and k != 'city'}
            # comp1 comp2 comp3 represent top three complaints for zip code
            # desc1 desc2 desc3 desc4 desc5 represent top three descriptors of complaints for zip code
            comp1 = ''
            comp2 = ''
            comp3 = ''
            desc1 = ''
            desc2 = ''
            desc3 = ''
            desc4 = ''
            desc5 = ''
            c_dict_len = len(complaints_dict)
            d_dict_len = len(descriptors_dict)
            if c_dict_len < 3 and c_dict_len != 0:
                # Less than three types of complaints, display only the top one
                top_complaint = nlargest(1, complaints_dict.items(), key=lambda x: x[1])
                comp1 = "{}: {}: {}%".format(top_complaint[0][0], top_complaint[0][1], round(top_complaint[0][1]/total_complaints * 100, 2))
            elif c_dict_len != 0:
                # Three or more complaint types, can compute top 3
                top_n_complaints = nlargest(3, complaints_dict.items(), key=lambda x: x[1])
                comp1 = "{}: {}: {}%".format(top_n_complaints[0][0], top_n_complaints[0][1], round(top_n_complaints[0][1]/total_complaints * 100, 2))
                comp2 = "{}: {}: {}%".format(top_n_complaints[1][0], top_n_complaints[1][1], round(top_n_complaints[1][1]/total_complaints * 100 ,2))
                comp3 = "{}: {}: {}%".format(top_n_complaints[2][0], top_n_complaints[2][1], round(top_n_complaints[2][1]/total_complaints * 100 ,2))
            if d_dict_len < 3 and d_dict_len != 0:
                # Less than three types of descriptors, display only the top one
                top_n_descriptors = nlargest(1, descriptors_dict.items(), key=lambda x: x[1])
                desc1 = "{}: {}: {}%".format(top_n_descriptors[0][0], top_n_descriptors[0][1], round(top_n_descriptors[0][1]/total_complaints * 100, 2))
            elif d_dict_len < 5 and d_dict_len != 0:
                # Between 3 and 4 descriptors, compute top 3
                top_n_descriptors = nlargest(3, descriptors_dict.items(), key=lambda x: x[1])
                desc1 = "{}: {}: {}%".format(top_n_descriptors[0][0], top_n_descriptors[0][1], round(top_n_descriptors[0][1]/total_complaints * 100, 2))
                desc2 = "{}: {}: {}%".format(top_n_descriptors[1][0], top_n_descriptors[1][1], round(top_n_descriptors[1][1]/total_complaints * 100, 2))
                desc3 = "{}: {}: {}%".format(top_n_descriptors[2][0], top_n_descriptors[2][1], round(top_n_descriptors[2][1]/total_complaints * 100, 2))
            elif d_dict_len != 0:
                # 5 or more descriptors, compute top 5
                top_n_descriptors = nlargest(5, descriptors_dict.items(), key=lambda x: x[1])
                desc1 = "{}: {}: {}%".format(top_n_descriptors[0][0], top_n_descriptors[0][1], round(top_n_descriptors[0][1]/total_complaints * 100, 2))
                desc2 = "{}: {}: {}%".format(top_n_descriptors[1][0], top_n_descriptors[1][1], round(top_n_descriptors[1][1]/total_complaints * 100, 2))
                desc3 = "{}: {}: {}%".format(top_n_descriptors[2][0], top_n_descriptors[2][1], round(top_n_descriptors[2][1]/total_complaints * 100, 2))
                desc4 = "{}: {}: {}%".format(top_n_descriptors[3][0], top_n_descriptors[3][1], round(top_n_descriptors[3][1]/total_complaints * 100, 2))
                desc5 = "{}: {}: {}%".format(top_n_descriptors[4][0], top_n_descriptors[4][1], round(top_n_descriptors[4][1]/total_complaints * 100, 2))
            yield (zip_code, (int(total_complaints), comp1, comp2, comp3, desc1, desc2, desc3, desc4, desc5, city))
    
result_rdd = zip_complaints_rdd.mapPartitions(topn)
result_rdd.collect()
# Out:
# [('10461',
#   (2,
#    'STREET CONDITION: 1: 50.0%',
#    '',
#    '',
#    '"Rough  Pitted or Cracked Roads": 1: 50.0%',
#    '',
#    '',
#    '',
#    '',
#    'Bronx')),
#  ('10128',
#   (1,
#    'STREET CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Plate Condition - Noisy: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'New york')),
#  ('11375',
#   (1,
#    'STREET LIGHT CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Street Light Out: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'Forest hills')),
#  ('11385',
#   (1,
#    'STREET CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Cave-in: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'Ridgewood')),
#  ('10001',
#   (1,
#    'STREET CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Pothole: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'New york')),
#  ('10312',
#   (1,
#    'STREET CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Pothole: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'Staten island')),
#  ('10314',
#   (1,
#    'STREET LIGHT CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Street Light Out: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'Staten island')),
#  ('10306',
#   (1,
#    'STREET CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Pothole: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'Staten island')),
#  ('10016',
#   (1,
#    'STREET CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Pothole: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'New york')),
#  ('10014',
#   (1,
#    'STREET CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Pothole: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'New york')),
#  ('10022',
#   (1,
#    'STREET CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Plate Condition - Noisy: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'New york')),
#  ('11412',
#   (1,
#    'STREET CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Pothole: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'Saint albans')),
#  ('11415',
#   (1,
#    'STREET LIGHT CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Street Light Out: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'Kew gardens')),
#  ('11231',
#   (2,
#    'STREET CONDITION: 1: 50.0%',
#    '',
#    '',
#    'Pothole: 1: 50.0%',
#    '',
#    '',
#    '',
#    '',
#    'Brooklyn')),
#  ('11232',
#   (1,
#    'STREET LIGHT CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Street Light Out: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'Brooklyn')),
#  ('11237',
#   (1,
#    'STREET CONDITION: 1: 100.0%',
#    '',
#    '',
#    '"Rough  Pitted or Cracked Roads": 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'Queens')),
#  ('11210',
#   (1,
#    'STREET CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Pothole: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'Brooklyn')),
#  ('11211',
#   (1,
#    'STREET CONDITION: 1: 100.0%',
#    '',
#    '',
#    '"Rough  Pitted or Cracked Roads": 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'Brooklyn')),
#  ('11217',
#   (1,
#    'STREET SIGN - DAMAGED: 1: 100.0%',
#    '',
#    '',
#    '"No Parking  Standing  Stopping": 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'Brooklyn')),
#  ('11220',
#   (1,
#    'STREET CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Plate Condition - Open: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'Brooklyn')),
#  ('11203',
#   (1,
#    'STREET CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Pothole: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'Brooklyn')),
#  ('11219',
#   (1,
#    'STREET CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Plate Condition - Noisy: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'Brooklyn')),
#  ('11207',
#   (1,
#    'STREET LIGHT CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Street Light Out: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'Brooklyn')),
#  ('11434',
#   (1,
#    'STREET CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Pothole: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'Jamaica')),
#  ('11427',
#   (1,
#    'STREET CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Pothole: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'Queens village')),
#  ('11358',
#   (1,
#    'STREET LIGHT CONDITION: 1: 100.0%',
#    '',
#    '',
#    'Street Light Out: 1: 100.0%',
#    '',
#    '',
#    '',
#    '',
#    'Flushing'))]

# %%
def combine(agg_dict, record_dict):
        for key, value in record_dict.items():
            if key != "city":
                agg_dict[key] = agg_dict.get(key, 0) + value
        return agg_dict
    
aggregate_dict = zip_complaints_rdd.map(lambda x: x[1]) \
                                   .fold({}, combine)
totals = sorted(aggregate_dict.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('total_complaints', 28),
#  ('STREET CONDITION', 19),
#  ('Pothole', 11),
#  ('STREET LIGHT CONDITION', 7),
#  ('Street Light Out', 7),
#  ('Plate Condition - Noisy', 3),
#  ('"Rough  Pitted or Cracked Roads"', 3),
#  ('Plate Condition - Open', 1),
#  ('STREET SIGN - MISSING', 1),
#  ('Stop', 1),
#  ('"No Parking  Standing  Stopping"', 1),
#  ('Cave-in', 1),
#  ('STREET SIGN - DAMAGED', 1)]

# %%
# result_rdd.coalesce(1).saveAsTextFile("./Results/three_one_one_results")
# sc.parallelize(totals).coalesce(1).saveAsTextFile("./Results/three_one_one_totals")
